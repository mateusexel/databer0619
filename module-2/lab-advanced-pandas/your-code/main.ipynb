# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:
import pandas as pd
import numpy as np
admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:
admissions.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:
admissions.index=admissions['Serial No.']
admissions.head()
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        316          104                  3  3.0  3.5
# 3                    3        322          110                  3  3.5  2.5
# 4                    4        314          103                  2  2.0  3.0
# 5                    5        330          115                  5  4.5  3.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1             0.92
# 2           8.00         1             0.72
# 3           8.67         1             0.80
# 4           8.21         0             0.65
# 5           9.34         1             0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# Your code here:

admissions.set_index(['Serial No.','GRE Score', 'CGPA'], inplace=True)
admissions.head()
# Out:
#                            TOEFL Score  University Rating  SOP  LOR  Research  \
# Serial No. GRE Score CGPA
# 1          337       9.65          118                  4  4.5  4.5         1
# 2          316       8.00          104                  3  3.0  3.5         1
# 3          322       8.67          110                  3  3.5  2.5         1
# 4          314       8.21          103                  2  2.0  3.0         0
# 5          330       9.34          115                  5  4.5  3.0         1
#
#                            Chance of Admit
# Serial No. GRE Score CGPA
# 1          337       9.65             0.92
# 2          316       8.00             0.72
# 3          322       8.67             0.80
# 4          314       8.21             0.65
# 5          330       9.34             0.90

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:
admissions.reset_index(['GRE Score', 'CGPA'], inplace=True)

# %%
admissions.head()
# Out:
#             GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                 337  9.65          118                  4  4.5  4.5
# 2                 316  8.00          104                  3  3.0  3.5
# 3                 322  8.67          110                  3  3.5  2.5
# 4                 314  8.21          103                  2  2.0  3.0
# 5                 330  9.34          115                  5  4.5  3.0
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.72
# 3                  1             0.80
# 4                  0             0.65
# 5                  1             0.90

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:

admissions.query('CGPA > 9')
# Out:
#             GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                 337  9.65          118                  4  4.5  4.5
# 5                 330  9.34          115                  5  4.5  3.0
# 11                328  9.10          112                  4  4.0  4.5
# 20                328  9.50          116                  5  5.0  5.0
# 21                334  9.70          119                  5  5.0  4.5
# 22                336  9.80          119                  5  4.0  3.5
# 29                338  9.40          118                  4  3.0  4.5
# 30                340  9.60          114                  5  4.0  4.0
# 31                331  9.80          112                  5  4.0  5.0
# 32                320  9.20          110                  5  5.0  5.0
# 40                332  9.10          117                  4  4.5  4.0
# 41                326  9.40          113                  5  4.5  4.0
# 42                322  9.10          110                  5  5.0  4.0
# 43                329  9.30          114                  5  4.0  5.0
# 44                339  9.70          119                  5  4.5  4.0
# 63                327  9.02          114                  3  3.0  3.0
# 65                318  9.22          109                  3  3.5  4.0
# 66                328  9.16          115                  4  4.5  4.0
# 67                332  9.64          118                  5  5.0  5.0
# 68                336  9.76          112                  5  5.0  5.0
# 69                321  9.45          111                  5  5.0  5.0
# 70                314  9.04          108                  4  4.5  4.0
# 78                340  9.50          120                  4  5.0  5.0
# 79                320  9.22          110                  5  5.0  4.5
# 80                322  9.36          115                  5  4.0  4.5
# 81                340  9.45          115                  5  4.5  4.5
# 94                332  9.24          119                  4  5.0  4.5
# 100               326  9.05          112                  3  3.5  3.0
# 102               329  9.18          111                  4  4.5  4.5
# 103               338  9.46          117                  4  3.5  4.5
# ...               ...   ...          ...                ...  ...  ...
# 247               331  9.34          119                  4  5.0  4.5
# 248               327  9.13          108                  5  5.0  3.5
# 256               327  9.14          113                  4  4.5  5.0
# 264               329  9.45          113                  5  5.0  4.5
# 269               317  9.11          110                  3  4.0  4.5
# 272               340  9.66          112                  4  5.0  4.5
# 273               331  9.26          116                  5  4.0  4.0
# 274               336  9.19          118                  5  4.5  4.0
# 275               324  9.08          114                  5  5.0  4.5
# 276               314  9.02          104                  4  5.0  5.0
# 285               320  9.11          120                  3  4.0  4.5
# 286               330  9.24          114                  3  4.5  4.5
# 294               323  9.10          110                  3  4.0  3.5
# 299               328  9.18          108                  4  4.5  4.0
# 312               326  9.14          116                  3  3.5  4.0
# 323               332  9.47          118                  5  5.0  5.0
# 347               334  9.54          116                  4  4.0  3.5
# 348               338  9.23          115                  5  4.5  5.0
# 351               330  9.17          114                  4  4.5  3.0
# 357               324  9.22          110                  3  3.5  3.0
# 358               336  9.62          119                  4  4.5  4.0
# 368               324  9.15          110                  4  4.5  4.0
# 370               340  9.74          113                  4  5.0  5.0
# 371               335  9.82          117                  5  5.0  5.0
# 378               326  9.12          112                  4  4.0  3.5
# 380               329  9.23          111                  4  4.5  4.0
# 381               324  9.04          110                  3  3.5  3.5
# 382               325  9.11          107                  3  3.0  3.5
# 383               330  9.45          116                  4  5.0  4.5
# 385               333  9.66          117                  4  5.0  4.0
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 5                  1             0.90
# 11                 1             0.78
# 20                 1             0.94
# 21                 1             0.95
# 22                 1             0.97
# 29                 1             0.91
# 30                 1             0.90
# 31                 1             0.94
# 32                 1             0.88
# 40                 0             0.87
# 41                 1             0.91
# 42                 1             0.88
# 43                 1             0.86
# 44                 0             0.89
# 63                 0             0.61
# 65                 1             0.68
# 66                 1             0.78
# 67                 1             0.94
# 68                 1             0.96
# 69                 1             0.93
# 70                 1             0.84
# 78                 1             0.96
# 79                 1             0.92
# 80                 1             0.92
# 81                 1             0.94
# 94                 1             0.90
# 100                1             0.74
# 102                1             0.87
# 103                1             0.91
# ...              ...              ...
# 247                1             0.90
# 248                1             0.87
# 256                0             0.83
# 264                1             0.89
# 269                1             0.80
# 272                1             0.94
# 273                1             0.93
# 274                1             0.92
# 275                1             0.89
# 276                0             0.82
# 285                0             0.86
# 286                1             0.90
# 294                1             0.79
# 299                1             0.84
# 312                1             0.81
# 323                1             0.94
# 347                1             0.93
# 348                1             0.91
# 351                1             0.86
# 357                1             0.89
# 358                1             0.95
# 368                1             0.82
# 370                1             0.96
# 371                1             0.96
# 378                1             0.84
# 380                1             0.89
# 381                1             0.82
# 382                1             0.84
# 383                1             0.91
# 385                1             0.95
#
# [110 rows x 8 columns]

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Your code here:

admissions.query(('CGPA > 9') and ('SOP < 3.5')).mean()
# Out:
# GRE Score            310.071856
# CGPA                   8.188323
# TOEFL Score          103.449102
# University Rating      2.287425
# SOP                    2.413174
# LOR                    2.814371
# Research               0.317365
# Chance of Admit        0.634072
# dtype: float64

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    # This function takes a column from a dataframe and returns a standardized column by subtracting the column's mean
    # and dividing by the column's standard deviation.
#     mean=col.mean()
#     std=col.std()
#     stdcol=[]
#     for i in col:
#         stdcol.append((i-mean)/std)
    
    return (col-np.mean(col))/np.std(col)
    # Your code here:

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:
admissions['CGPA_std']=standardize(admissions.CGPA)
admissions['GRE_std']=standardize(admissions['GRE Score'])
admissions['LOR_std']=standardize(admissions.LOR)

# %%
admissions.head()
# Out:
#             GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                 337  9.65          118                  4  4.5  4.5
# 2                 316  8.00          104                  3  3.0  3.5
# 3                 322  8.67          110                  3  3.5  2.5
# 4                 314  8.21          103                  2  2.0  3.0
# 5                 330  9.34          115                  5  4.5  3.0
#
#             Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# Serial No.
# 1                  1             0.92  1.750174  1.755663  1.193197
# 2                  1             0.72 -0.992501 -0.063450  0.076840
# 3                  1             0.80  0.121191  0.456297 -1.039517
# 4                  0             0.65 -0.643433 -0.236698 -0.481338
# 5                  1             0.90  1.234884  1.149292 -0.481338

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:

from random import choices
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# Your code here:
admissions['DECISION']=admissions.lookup(admissions.index, decision_choice)
admissions.head()
# Out:
#             GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                 337  9.65          118                  4  4.5  4.5
# 2                 316  8.00          104                  3  3.0  3.5
# 3                 322  8.67          110                  3  3.5  2.5
# 4                 314  8.21          103                  2  2.0  3.0
# 5                 330  9.34          115                  5  4.5  3.0
#
#             Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  DECISION
# Serial No.
# 1                  1             0.92  1.750174  1.755663  1.193197  1.193197
# 2                  1             0.72 -0.992501 -0.063450  0.076840 -0.992501
# 3                  1             0.80  0.121191  0.456297 -1.039517  0.121191
# 4                  0             0.65 -0.643433 -0.236698 -0.481338 -0.236698
# 5                  1             0.90  1.234884  1.149292 -0.481338  1.234884

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# Your code here:
# admissions['DECISIONFINALE'] = 1 if admissions[admissions['DECISION']] > 0.8 else 0
admissions['DECISIONFINALE'] = np.where(admissions['DECISION'] > 0.8 , 1,0)
admissions.head()
# Out:
#             GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                 337  9.65          118                  4  4.5  4.5
# 2                 316  8.00          104                  3  3.0  3.5
# 3                 322  8.67          110                  3  3.5  2.5
# 4                 314  8.21          103                  2  2.0  3.0
# 5                 330  9.34          115                  5  4.5  3.0
#
#             Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  DECISION  \
# Serial No.
# 1                  1             0.92  1.750174  1.755663  1.193197  1.193197
# 2                  1             0.72 -0.992501 -0.063450  0.076840 -0.992501
# 3                  1             0.80  0.121191  0.456297 -1.039517  0.121191
# 4                  0             0.65 -0.643433 -0.236698 -0.481338 -0.236698
# 5                  1             0.90  1.234884  1.149292 -0.481338  1.234884
#
#             DECISIONFINALE
# Serial No.
# 1                        1
# 2                        0
# 3                        0
# 4                        0
# 5                        1

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:

admissions.DECISIONFINALE.sum()
# Out:
# 93

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# Your code here:

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:
