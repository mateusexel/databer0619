# %%
import json;
import requests;
from pandas.io.json import json_normalize;
response = requests.get('https://api.github.com/repos/ironhack-datalabs/databer0619/forks', auth=("mateusexel","1c538fefb33de2a88ab9fc44f66cb8f9f3f21ba9"))
print(response)
data = response.json();
# Out:
# <Response [200]>

# %%
forks=json_normalize(data)
forks.head()
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/NachoMartinezJ/da...     False
# 1  https://api.github.com/repos/mateusexel/databe...     False
# 2  https://api.github.com/repos/sveninja/databer0...     False
# 3  https://api.github.com/repos/jonasgranath/data...     False
# 4  https://api.github.com/repos/idoukas/databer06...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/NachoMartinezJ/da...
# 1  https://api.github.com/repos/mateusexel/databe...
# 2  https://api.github.com/repos/sveninja/databer0...
# 3  https://api.github.com/repos/jonasgranath/data...
# 4  https://api.github.com/repos/idoukas/databer06...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/NachoMartinezJ/da...
# 1  https://api.github.com/repos/mateusexel/databe...
# 2  https://api.github.com/repos/sveninja/databer0...
# ...

# %%
languages=[]
for language in forks['language']:
    if language not in languages:
        languages.append(language);
print(languages)
# Out:
# ['Jupyter Notebook']

# %%
forks['']

# %%
forks.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'disabled',
#        'downloads_url', 'events_url', 'fork', 'forks', 'forks_count',
#        'forks_url', 'full_name', 'git_commits_url', 'git_refs_url',
#        'git_tags_url', 'git_url', 'has_downloads', 'has_issues', 'has_pages',
#        'has_projects', 'has_wiki', 'homepage', 'hooks_url', 'html_url', 'id',
#        'issue_comment_url', 'issue_events_url', 'issues_url', 'keys_url',
#        'labels_url', 'language', 'languages_url', 'license.key',
#        'license.name', 'license.node_id', 'license.spdx_id', 'license.url',
#        'merges_url', 'milestones_url', 'mirror_url', 'name', 'node_id',
#        'notifications_url', 'open_issues', 'open_issues_count',
# ...

# %%
responsecommits = requests.get('https://api.github.com/repos/ironhack-datalabs/databer0619/commits', auth=("mateusexel","1c538fefb33de2a88ab9fc44f66cb8f9f3f21ba9"))
print(response)
datacommits = responsecommits.json();
forkscommits=json_normalize(datacommits)
forkscommits.shape

# response = requests.get('https://api.github.com/repos/ironhack-datalabs/databer0619/forks')
# print(response)
# data = response.json();
# Out:
# <Response [200]>
# (30, 57)

# %%
responsescavenger = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger', auth=("mateusexel","1c538fefb33de2a88ab9fc44f66cb8f9f3f21ba9"))
print(response)
datascavenger = responsescavenger.json();
forksscavenger=json_normalize(datascavenger)
forksscavenger.head()
# Out:
# <Response [200]>
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/ironhack-datalabs...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                         branches_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                            clone_url  \
# 0  https://github.com/ironhack-datalabs/scavenger...
#
#                                    collaborators_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
#                                          commits_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
#
# ...
