# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://en.zalando.de/api/catalog/articles?categories=watches-men&limit=84&offset=0&sort=price_desc'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
# Your code

response = {
total_count: 1713,
pagination: {
page_count: 21,
current_page: 1,
per_page: 84
},
sort: "price_desc",
articles: [
{
sku: "VEF52M006-F11",
name: "SPORT TECH - Chronograph watch - gold-coloured/gun",
price: {
original: "1.419,95 €",
promotional: "1.419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-f11",
media: [
{
path: "VE/F5/2M/00/6F/11/VEF52M006-F11@4.3.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/6F/11/VEF52M006-F11@3.3.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M006-F11",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-f11",
media: [
{
path: "VE/F5/2M/00/6F/11/VEF52M006-F11@4.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - gold-coloured/gun",
sizes: [
"One Size"
],
price: {
original: "1.419,95 €",
promotional: "1.419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-K11",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-k11",
media: [
{
path: "VE/F5/2M/00/6K/11/VEF52M006-K11@4.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - blue",
sizes: [
"One Size"
],
price: {
original: "1.229,95 €",
promotional: "1.229,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-F12",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-f12",
media: [
{
path: "VE/F5/2M/00/6F/12/VEF52M006-F12@8.6.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - all gold-coloured",
sizes: [
"One Size"
],
price: {
original: "1.419,95 €",
promotional: "1.419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-Q11",
url_key: "versace-watches-sport-tech-chronograph-watch-brown-vef52m006-q11",
media: [
{
path: "VE/F5/2M/00/6Q/11/VEF52M006-Q11@8.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - brown",
sizes: [
"One Size"
],
price: {
original: "1.229,95 €",
promotional: "1.229,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "VEF52M006-F12",
name: "SPORT TECH - Chronograph watch - all gold-coloured",
price: {
original: "1.419,95 €",
promotional: "1.419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-f12",
media: [
{
path: "VE/F5/2M/00/6F/12/VEF52M006-F12@8.6.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/6F/12/VEF52M006-F12@3.6.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M006-F12",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-f12",
media: [
{
path: "VE/F5/2M/00/6F/12/VEF52M006-F12@8.6.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - all gold-coloured",
sizes: [
"One Size"
],
price: {
original: "1.419,95 €",
promotional: "1.419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-K11",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-k11",
media: [
{
path: "VE/F5/2M/00/6K/11/VEF52M006-K11@4.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - blue",
sizes: [
"One Size"
],
price: {
original: "1.229,95 €",
promotional: "1.229,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-Q11",
url_key: "versace-watches-sport-tech-chronograph-watch-brown-vef52m006-q11",
media: [
{
path: "VE/F5/2M/00/6Q/11/VEF52M006-Q11@8.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - brown",
sizes: [
"One Size"
],
price: {
original: "1.229,95 €",
promotional: "1.229,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-F11",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-f11",
media: [
{
path: "VE/F5/2M/00/6F/11/VEF52M006-F11@4.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - gold-coloured/gun",
sizes: [
"One Size"
],
price: {
original: "1.419,95 €",
promotional: "1.419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "VEF52M007-F12",
name: "PALAZZO EMPIRE - Watch - rosegold-coloured/gunmetal",
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-palazzo-empire-watch-rosegold-colouredgunmetal-vef52m007-f12",
media: [
{
path: "VE/F5/2M/00/7F/12/VEF52M007-F12@6.4.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/7F/12/VEF52M007-F12@9.3.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M007-F12",
url_key: "versace-watches-palazzo-empire-watch-rosegold-colouredgunmetal-vef52m007-f12",
media: [
{
path: "VE/F5/2M/00/7F/12/VEF52M007-F12@6.4.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - rosegold-coloured/gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-C11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-c11",
media: [
{
path: "VE/F5/2M/00/7C/11/VEF52M007-C11@6.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-F11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-f11",
media: [
{
path: "VE/F5/2M/00/7F/11/VEF52M007-F11@7.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - gold-coloured/gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-Q11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-q11",
media: [
{
path: "VE/F5/2M/00/7Q/11/VEF52M007-Q11@6.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - all black",
sizes: [
"One Size"
],
price: {
original: "1.189,95 €",
promotional: "1.189,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "VEF52M007-F11",
name: "PALAZZO EMPIRE - Watch - gold-coloured/gunmetal",
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-palazzo-empire-watch-vef52m007-f11",
media: [
{
path: "VE/F5/2M/00/7F/11/VEF52M007-F11@7.5.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/7F/11/VEF52M007-F11@8.4.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M007-F11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-f11",
media: [
{
path: "VE/F5/2M/00/7F/11/VEF52M007-F11@7.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - gold-coloured/gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-C11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-c11",
media: [
{
path: "VE/F5/2M/00/7C/11/VEF52M007-C11@6.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-Q11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-q11",
media: [
{
path: "VE/F5/2M/00/7Q/11/VEF52M007-Q11@6.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - all black",
sizes: [
"One Size"
],
price: {
original: "1.189,95 €",
promotional: "1.189,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-F12",
url_key: "versace-watches-palazzo-empire-watch-rosegold-colouredgunmetal-vef52m007-f12",
media: [
{
path: "VE/F5/2M/00/7F/12/VEF52M007-F12@6.4.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - rosegold-coloured/gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "VEF52M007-C11",
name: "PALAZZO EMPIRE - Watch - gunmetal",
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-palazzo-empire-watch-vef52m007-c11",
media: [
{
path: "VE/F5/2M/00/7C/11/VEF52M007-C11@6.5.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/7C/11/VEF52M007-C11@9.4.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M007-C11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-c11",
media: [
{
path: "VE/F5/2M/00/7C/11/VEF52M007-C11@6.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-F11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-f11",
media: [
{
path: "VE/F5/2M/00/7F/11/VEF52M007-F11@7.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - gold-coloured/gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-Q11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-q11",
media: [
{
path: "VE/F5/2M/00/7Q/11/VEF52M007-Q11@6.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - all black",
sizes: [
"One Size"
],
price: {
original: "1.189,95 €",
promotional: "1.189,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-F12",
url_key: "versace-watches-palazzo-empire-watch-rosegold-colouredgunmetal-vef52m007-f12",
media: [
{
path: "VE/F5/2M/00/7F/12/VEF52M007-F12@6.4.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - rosegold-coloured/gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "VEF52M006-Q11",
name: "SPORT TECH - Chronograph watch - brown",
price: {
original: "1.229,95 €",
promotional: "1.229,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-sport-tech-chronograph-watch-brown-vef52m006-q11",
media: [
{
path: "VE/F5/2M/00/6Q/11/VEF52M006-Q11@8.3.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/6Q/11/VEF52M006-Q11@3.3.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M006-Q11",
url_key: "versace-watches-sport-tech-chronograph-watch-brown-vef52m006-q11",
media: [
{
path: "VE/F5/2M/00/6Q/11/VEF52M006-Q11@8.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - brown",
sizes: [
"One Size"
],
price: {
original: "1.229,95 €",
promotional: "1.229,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-K11",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-k11",
media: [
{
path: "VE/F5/2M/00/6K/11/VEF52M006-K11@4.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - blue",
sizes: [
"One Size"
],
price: {
original: "1.229,95 €",
promotional: "1.229,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-F12",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-f12",
media: [
{
path: "VE/F5/2M/00/6F/12/VEF52M006-F12@8.6.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - all gold-coloured",
sizes: [
"One Size"
],
price: {
original: "1.419,95 €",
promotional: "1.419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-F11",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-f11",
media: [
{
path: "VE/F5/2M/00/6F/11/VEF52M006-F11@4.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - gold-coloured/gun",
sizes: [
"One Size"
],
price: {
original: "1.419,95 €",
promotional: "1.419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "VEF52M006-K11",
name: "SPORT TECH - Chronograph watch - blue",
price: {
original: "1.229,95 €",
promotional: "1.229,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-k11",
media: [
{
path: "VE/F5/2M/00/6K/11/VEF52M006-K11@4.3.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/6K/11/VEF52M006-K11@3.3.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M006-K11",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-k11",
media: [
{
path: "VE/F5/2M/00/6K/11/VEF52M006-K11@4.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - blue",
sizes: [
"One Size"
],
price: {
original: "1.229,95 €",
promotional: "1.229,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-F12",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-f12",
media: [
{
path: "VE/F5/2M/00/6F/12/VEF52M006-F12@8.6.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - all gold-coloured",
sizes: [
"One Size"
],
price: {
original: "1.419,95 €",
promotional: "1.419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-Q11",
url_key: "versace-watches-sport-tech-chronograph-watch-brown-vef52m006-q11",
media: [
{
path: "VE/F5/2M/00/6Q/11/VEF52M006-Q11@8.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - brown",
sizes: [
"One Size"
],
price: {
original: "1.229,95 €",
promotional: "1.229,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M006-F11",
url_key: "versace-watches-sport-tech-chronograph-watch-vef52m006-f11",
media: [
{
path: "VE/F5/2M/00/6F/11/VEF52M006-F11@4.3.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "SPORT TECH - Chronograph watch - gold-coloured/gun",
sizes: [
"One Size"
],
price: {
original: "1.419,95 €",
promotional: "1.419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "VEF52M007-Q11",
name: "PALAZZO EMPIRE - Watch - all black",
price: {
original: "1.189,95 €",
promotional: "1.189,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-palazzo-empire-watch-vef52m007-q11",
media: [
{
path: "VE/F5/2M/00/7Q/11/VEF52M007-Q11@6.5.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/7Q/11/VEF52M007-Q11@9.4.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M007-Q11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-q11",
media: [
{
path: "VE/F5/2M/00/7Q/11/VEF52M007-Q11@6.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - all black",
sizes: [
"One Size"
],
price: {
original: "1.189,95 €",
promotional: "1.189,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-C11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-c11",
media: [
{
path: "VE/F5/2M/00/7C/11/VEF52M007-C11@6.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-F11",
url_key: "versace-watches-palazzo-empire-watch-vef52m007-f11",
media: [
{
path: "VE/F5/2M/00/7F/11/VEF52M007-F11@7.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - gold-coloured/gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "VEF52M007-F12",
url_key: "versace-watches-palazzo-empire-watch-rosegold-colouredgunmetal-vef52m007-f12",
media: [
{
path: "VE/F5/2M/00/7F/12/VEF52M007-F12@6.4.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "PALAZZO EMPIRE - Watch - rosegold-coloured/gunmetal",
sizes: [
"One Size"
],
price: {
original: "1.359,95 €",
promotional: "1.359,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "VEF52M008-F11",
name: "UNIVERS - Watch - gold-coloured",
price: {
original: "959,95 €",
promotional: "959,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-univers-watch-gold-coloured-vef52m008-f11",
media: [
{
path: "VE/F5/2M/00/8F/11/VEF52M008-F11@7.1.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/8F/11/VEF52M008-F11@5.1.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M008-F11",
url_key: "versace-watches-univers-watch-gold-coloured-vef52m008-f11",
media: [
{
path: "VE/F5/2M/00/8F/11/VEF52M008-F11@7.1.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "UNIVERS - Watch - gold-coloured",
sizes: [
"One Size"
],
price: {
original: "959,95 €",
promotional: "959,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "SZ752M00F-D11",
name: "Chronograph watch - silver-coloured",
price: {
original: "1.200,00 €",
promotional: "947,15 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "seiko-chronograph-watch-silver-coloured-sz752m00f-d11",
media: [
{
path: "SZ/75/2M/00/FD/11/SZ752M00F-D11@3.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Seiko",
is_premium: false,
family_articles: [
{
sku: "SZ752M00F-D11",
url_key: "seiko-chronograph-watch-silver-coloured-sz752m00f-d11",
media: [
{
path: "SZ/75/2M/00/FD/11/SZ752M00F-D11@3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "1.200,00 €",
promotional: "947,15 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-21%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-21%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "C1552M04C-Q11",
name: "Chronograph watch - black",
price: {
original: "999,00 €",
promotional: "899,10 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-chronograph-watch-black-c1552m04c-q11",
media: [
{
path: "C1/55/2M/04/CQ/11/C1552M04C-Q11@3.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M04C-Q11",
url_key: "casio-chronograph-watch-black-c1552m04c-q11",
media: [
{
path: "C1/55/2M/04/CQ/11/C1552M04C-Q11@3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - black",
sizes: [
"One Size"
],
price: {
original: "999,00 €",
promotional: "899,10 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-10%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-10%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "C1552M03P-Q11",
name: "Chronograph watch - black",
price: {
original: "895,00 €",
promotional: "895,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-watch-black-c1552m03p-q11",
media: [
{
path: "C1/55/2M/03/PQ/11/C1552M03P-Q11@7.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M03P-Q11",
url_key: "casio-watch-black-c1552m03p-q11",
media: [
{
path: "C1/55/2M/03/PQ/11/C1552M03P-Q11@7.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - black",
sizes: [
"One Size"
],
price: {
original: "895,00 €",
promotional: "895,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "VEF52M005-D12",
name: "GLAZE - Watch - bracelet silver-coloured/gold-coloured",
price: {
original: "1.189,95 €",
promotional: "889,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-glaze-watch-vef52m005-d12",
media: [
{
path: "VE/F5/2M/00/5D/12/VEF52M005-D12@2.5.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/5D/12/VEF52M005-D12@3.5.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M005-D12",
url_key: "versace-watches-glaze-watch-vef52m005-d12",
media: [
{
path: "VE/F5/2M/00/5D/12/VEF52M005-D12@2.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "GLAZE - Watch - bracelet silver-coloured/gold-coloured",
sizes: [
"One Size"
],
price: {
original: "1.189,95 €",
promotional: "889,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M005-D11",
url_key: "versace-watches-glaze-watch-silver-coloured-vef52m005-d11",
media: [
{
path: "VE/F5/2M/00/5D/11/VEF52M005-D11@7.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "GLAZE - Watch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "1.019,95 €",
promotional: "764,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "VEF52M001-D11",
name: "UNIVERS - Watch - silver-coloured",
price: {
original: "859,95 €",
promotional: "859,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-univers-watch-silver-coloured-vef52m001-d11",
media: [
{
path: "VE/F5/2M/00/1D/11/VEF52M001-D11@8.1.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/1D/11/VEF52M001-D11@5.2.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M001-D11",
url_key: "versace-watches-univers-watch-silver-coloured-vef52m001-d11",
media: [
{
path: "VE/F5/2M/00/1D/11/VEF52M001-D11@8.1.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "UNIVERS - Watch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "859,95 €",
promotional: "859,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "VEF52M000-Q11",
name: "UNIVERS - Watch - darkblue/gold-coloured",
price: {
original: "859,95 €",
promotional: "859,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-univers-watch-darkbluegold-coloured-vef52m000-q11",
media: [
{
path: "VE/F5/2M/00/0Q/11/VEF52M000-Q11@5.4.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/0Q/11/VEF52M000-Q11@3.5.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M000-Q11",
url_key: "versace-watches-univers-watch-darkbluegold-coloured-vef52m000-q11",
media: [
{
path: "VE/F5/2M/00/0Q/11/VEF52M000-Q11@5.4.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "UNIVERS - Watch - darkblue/gold-coloured",
sizes: [
"One Size"
],
price: {
original: "859,95 €",
promotional: "859,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "C1552M02J-G11",
name: "Chronograph watch - red",
price: {
original: "899,00 €",
promotional: "809,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-chronograph-watch-red-c1552m02j-g11",
media: [
{
path: "C1/55/2M/02/JG/11/C1552M02J-G11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M02J-G11",
url_key: "casio-chronograph-watch-red-c1552m02j-g11",
media: [
{
path: "C1/55/2M/02/JG/11/C1552M02J-G11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - red",
sizes: [
"One Size"
],
price: {
original: "899,00 €",
promotional: "809,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-10%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-10%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "C1552M030-D11",
name: "Chronograph watch - silver-coloured",
price: {
original: "899,00 €",
promotional: "799,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-chronograph-watch-silver-coloured-c1552m030-d11",
media: [
{
path: "C1/55/2M/03/0D/11/C1552M030-D11@3.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M030-D11",
url_key: "casio-chronograph-watch-silver-coloured-c1552m030-d11",
media: [
{
path: "C1/55/2M/03/0D/11/C1552M030-D11@3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "899,00 €",
promotional: "799,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-11%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-11%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "VEF52M005-D11",
name: "GLAZE - Watch - silver-coloured",
price: {
original: "1.019,95 €",
promotional: "764,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-glaze-watch-silver-coloured-vef52m005-d11",
media: [
{
path: "VE/F5/2M/00/5D/11/VEF52M005-D11@7.5.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/5D/11/VEF52M005-D11@8.4.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M005-D11",
url_key: "versace-watches-glaze-watch-silver-coloured-vef52m005-d11",
media: [
{
path: "VE/F5/2M/00/5D/11/VEF52M005-D11@7.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "GLAZE - Watch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "1.019,95 €",
promotional: "764,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M005-D12",
url_key: "versace-watches-glaze-watch-vef52m005-d12",
media: [
{
path: "VE/F5/2M/00/5D/12/VEF52M005-D12@2.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "GLAZE - Watch - bracelet silver-coloured/gold-coloured",
sizes: [
"One Size"
],
price: {
original: "1.189,95 €",
promotional: "889,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "VEF52M004-O12",
name: "GLAZE - Watch - brown",
price: {
original: "1.019,95 €",
promotional: "764,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-glaze-watch-vef52m004-o12",
media: [
{
path: "VE/F5/2M/00/4O/12/VEF52M004-O12@7.4.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/4O/12/VEF52M004-O12@3.4.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M004-O12",
url_key: "versace-watches-glaze-watch-vef52m004-o12",
media: [
{
path: "VE/F5/2M/00/4O/12/VEF52M004-O12@7.4.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "GLAZE - Watch - brown",
sizes: [
"One Size"
],
price: {
original: "1.019,95 €",
promotional: "764,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M004-K11",
url_key: "versace-watches-glaze-watch-vef52m004-k11",
media: [
{
path: "VE/F5/2M/00/4K/11/VEF52M004-K11@7.4.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "GLAZE - Watch - blue",
sizes: [
"One Size"
],
price: {
original: "959,95 €",
promotional: "719,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M004-O11",
url_key: "versace-watches-glaze-watch-ivory-vef52m004-o11",
media: [
{
path: "VE/F5/2M/00/4O/11/VEF52M004-O11@7.8.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "GLAZE - Watch - ivory",
sizes: [
"One Size"
],
price: {
original: "1.019,95 €",
promotional: "764,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "VEF52M004-O11",
name: "GLAZE - Watch - ivory",
price: {
original: "1.019,95 €",
promotional: "764,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-glaze-watch-ivory-vef52m004-o11",
media: [
{
path: "VE/F5/2M/00/4O/11/VEF52M004-O11@7.8.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/4O/11/VEF52M004-O11@8.7.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M004-O11",
url_key: "versace-watches-glaze-watch-ivory-vef52m004-o11",
media: [
{
path: "VE/F5/2M/00/4O/11/VEF52M004-O11@7.8.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "GLAZE - Watch - ivory",
sizes: [
"One Size"
],
price: {
original: "1.019,95 €",
promotional: "764,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M004-O12",
url_key: "versace-watches-glaze-watch-vef52m004-o12",
media: [
{
path: "VE/F5/2M/00/4O/12/VEF52M004-O12@7.4.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "GLAZE - Watch - brown",
sizes: [
"One Size"
],
price: {
original: "1.019,95 €",
promotional: "764,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M004-K11",
url_key: "versace-watches-glaze-watch-vef52m004-k11",
media: [
{
path: "VE/F5/2M/00/4K/11/VEF52M004-K11@7.4.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "GLAZE - Watch - blue",
sizes: [
"One Size"
],
price: {
original: "959,95 €",
promotional: "719,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "BRO52M00F-D11",
name: "Watch - silver-coloured",
price: {
original: "720,00 €",
promotional: "720,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "bruno-soehnle-watch-silver-coloured-bro52m00f-d11",
media: [
{
path: "BR/O5/2M/00/FD/11/BRO52M00F-D11@3.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Bruno Söhnle",
is_premium: false,
family_articles: [
{
sku: "BRO52M00F-D11",
url_key: "bruno-soehnle-watch-silver-coloured-bro52m00f-d11",
media: [
{
path: "BR/O5/2M/00/FD/11/BRO52M00F-D11@3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "720,00 €",
promotional: "720,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "VEF52M004-K11",
name: "GLAZE - Watch - blue",
price: {
original: "959,95 €",
promotional: "719,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-glaze-watch-vef52m004-k11",
media: [
{
path: "VE/F5/2M/00/4K/11/VEF52M004-K11@7.4.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/4K/11/VEF52M004-K11@3.4.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF52M004-K11",
url_key: "versace-watches-glaze-watch-vef52m004-k11",
media: [
{
path: "VE/F5/2M/00/4K/11/VEF52M004-K11@7.4.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "GLAZE - Watch - blue",
sizes: [
"One Size"
],
price: {
original: "959,95 €",
promotional: "719,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M004-O12",
url_key: "versace-watches-glaze-watch-vef52m004-o12",
media: [
{
path: "VE/F5/2M/00/4O/12/VEF52M004-O12@7.4.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "GLAZE - Watch - brown",
sizes: [
"One Size"
],
price: {
original: "1.019,95 €",
promotional: "764,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M004-O11",
url_key: "versace-watches-glaze-watch-ivory-vef52m004-o11",
media: [
{
path: "VE/F5/2M/00/4O/11/VEF52M004-O11@7.8.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "GLAZE - Watch - ivory",
sizes: [
"One Size"
],
price: {
original: "1.019,95 €",
promotional: "764,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "C1552M035-Q11",
name: "Chronograph watch - black",
price: {
original: "799,00 €",
promotional: "719,10 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-chronograph-watch-black-c1552m035-q11",
media: [
{
path: "C1/55/2M/03/5Q/11/C1552M035-Q11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M035-Q11",
url_key: "casio-chronograph-watch-black-c1552m035-q11",
media: [
{
path: "C1/55/2M/03/5Q/11/C1552M035-Q11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - black",
sizes: [
"One Size"
],
price: {
original: "799,00 €",
promotional: "719,10 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-10%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-10%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "C1552M041-Q11",
name: "Chronograph watch - black",
price: {
original: "845,00 €",
promotional: "710,05 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-chronograph-watch-black-c1552m041-q11",
media: [
{
path: "C1/55/2M/04/1Q/11/C1552M041-Q11@9.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M041-Q11",
url_key: "casio-chronograph-watch-black-c1552m041-q11",
media: [
{
path: "C1/55/2M/04/1Q/11/C1552M041-Q11@9.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - black",
sizes: [
"One Size"
],
price: {
original: "845,00 €",
promotional: "710,05 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-16%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-16%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "C1552M03V-Q11",
name: "Watch - black",
price: {
original: "699,00 €",
promotional: "699,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-digital-watch-black-c1552m03v-q11",
media: [
{
path: "C1/55/2M/03/VQ/11/C1552M03V-Q11@2.2.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M03V-Q11",
url_key: "casio-digital-watch-black-c1552m03v-q11",
media: [
{
path: "C1/55/2M/03/VQ/11/C1552M03V-Q11@2.2.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - black",
sizes: [
"One Size"
],
price: {
original: "699,00 €",
promotional: "699,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "BRO52M00E-Q11",
name: "Watch - black",
price: {
original: "685,00 €",
promotional: "685,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "bruno-soehnle-watch-black-bro52m00e-q11",
media: [
{
path: "BR/O5/2M/00/EQ/11/BRO52M00E-Q11@3.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Bruno Söhnle",
is_premium: false,
family_articles: [
{
sku: "BRO52M00E-Q11",
url_key: "bruno-soehnle-watch-black-bro52m00e-q11",
media: [
{
path: "BR/O5/2M/00/EQ/11/BRO52M00E-Q11@3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - black",
sizes: [
"One Size"
],
price: {
original: "685,00 €",
promotional: "685,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "C1552M04L-Q11",
name: "G-Shock - Chronograph watch - black",
price: {
original: "899,00 €",
promotional: "676,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-g-shock-chronograph-watch-black-c1552m04l-q11",
media: [
{
path: "C1/55/2M/04/LQ/11/C1552M04L-Q11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M04L-Q11",
url_key: "casio-g-shock-chronograph-watch-black-c1552m04l-q11",
media: [
{
path: "C1/55/2M/04/LQ/11/C1552M04L-Q11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "G-Shock - Chronograph watch - black",
sizes: [
"One Size"
],
price: {
original: "899,00 €",
promotional: "676,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "C1552M042-Q11",
name: "Chronograph watch - black",
price: {
original: "799,00 €",
promotional: "667,20 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-chronograph-watch-black-c1552m042-q11",
media: [
{
path: "C1/55/2M/04/2Q/11/C1552M042-Q11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M042-Q11",
url_key: "casio-chronograph-watch-black-c1552m042-q11",
media: [
{
path: "C1/55/2M/04/2Q/11/C1552M042-Q11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - black",
sizes: [
"One Size"
],
price: {
original: "799,00 €",
promotional: "667,20 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-16%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-16%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "BRO52M00D-Q11",
name: "Chronograph watch - black",
price: {
original: "650,00 €",
promotional: "650,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "bruno-soehnle-chronograph-watch-black-bro52m00d-q11",
media: [
{
path: "BR/O5/2M/00/DQ/11/BRO52M00D-Q11@3.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Bruno Söhnle",
is_premium: false,
family_articles: [
{
sku: "BRO52M00D-Q11",
url_key: "bruno-soehnle-chronograph-watch-black-bro52m00d-q11",
media: [
{
path: "BR/O5/2M/00/DQ/11/BRO52M00D-Q11@3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - black",
sizes: [
"One Size"
],
price: {
original: "650,00 €",
promotional: "650,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "SZ752M00G-O11",
name: "Watch - brown",
price: {
original: "619,00 €",
promotional: "619,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "seiko-watch-brown-sz752m00g-o11",
media: [
{
path: "SZ/75/2M/00/GO/11/SZ752M00G-O11@5.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Seiko",
is_premium: false,
family_articles: [
{
sku: "SZ752M00G-O11",
url_key: "seiko-watch-brown-sz752m00g-o11",
media: [
{
path: "SZ/75/2M/00/GO/11/SZ752M00G-O11@5.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - brown",
sizes: [
"One Size"
],
price: {
original: "619,00 €",
promotional: "619,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "SZ752M00I-D11",
name: "Watch - silver/black",
price: {
original: "599,00 €",
promotional: "599,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "seiko-watch-silverblack-sz752m00i-d11",
media: [
{
path: "SZ/75/2M/00/ID/11/SZ752M00I-D11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Seiko",
is_premium: false,
family_articles: [
{
sku: "SZ752M00I-D11",
url_key: "seiko-watch-silverblack-sz752m00i-d11",
media: [
{
path: "SZ/75/2M/00/ID/11/SZ752M00I-D11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - silver/black",
sizes: [
"One Size"
],
price: {
original: "599,00 €",
promotional: "599,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "VEF54M001-Q11",
name: "V-CIRCLE THE MANIFESTO EDITION - Watch - black/brown",
price: {
original: "589,95 €",
promotional: "589,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-v-circle-the-manifesto-edition-watch-blackbrown-vef54m001-q11",
media: [
{
path: "VE/F5/4M/00/1Q/11/VEF54M001-Q11@11.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/4M/00/1Q/11/VEF54M001-Q11@10.1.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF54M001-Q11",
url_key: "versace-watches-v-circle-the-manifesto-edition-watch-blackbrown-vef54m001-q11",
media: [
{
path: "VE/F5/4M/00/1Q/11/VEF54M001-Q11@11.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "V-CIRCLE THE MANIFESTO EDITION - Watch - black/brown",
sizes: [
"One Size"
],
price: {
original: "589,95 €",
promotional: "589,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "VEF54M002-Q11",
name: "V-CIRCLE THE MANIFESTO EDITION - Watch - green/gold-coloured",
price: {
original: "589,95 €",
promotional: "589,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-v-circle-the-manifesto-edition-watch-blackgold-coloured-vef54m002-q11",
media: [
{
path: "VE/F5/4M/00/2Q/11/VEF54M002-Q11@8.2.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/4M/00/2Q/11/VEF54M002-Q11@5.3.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: false,
family_articles: [
{
sku: "VEF54M002-Q11",
url_key: "versace-watches-v-circle-the-manifesto-edition-watch-blackgold-coloured-vef54m002-q11",
media: [
{
path: "VE/F5/4M/00/2Q/11/VEF54M002-Q11@8.2.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "V-CIRCLE THE MANIFESTO EDITION - Watch - green/gold-coloured",
sizes: [
"One Size"
],
price: {
original: "589,95 €",
promotional: "589,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "BRO52M009-Q11",
name: "Watch - black",
price: {
original: "570,00 €",
promotional: "570,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "bruno-soehnle-watch-black-bro52m009-q11",
media: [
{
path: "BR/O5/2M/00/9Q/11/BRO52M009-Q11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Bruno Söhnle",
is_premium: false,
family_articles: [
{
sku: "BRO52M009-Q11",
url_key: "bruno-soehnle-watch-black-bro52m009-q11",
media: [
{
path: "BR/O5/2M/00/9Q/11/BRO52M009-Q11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - black",
sizes: [
"One Size"
],
price: {
original: "570,00 €",
promotional: "570,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "BRO52M00B-Q11",
name: "Watch - black",
price: {
original: "570,00 €",
promotional: "570,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "bruno-soehnle-watch-black-bro52m00b-q11",
media: [
{
path: "BR/O5/2M/00/BQ/11/BRO52M00B-Q11@3.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Bruno Söhnle",
is_premium: false,
family_articles: [
{
sku: "BRO52M00B-Q11",
url_key: "bruno-soehnle-watch-black-bro52m00b-q11",
media: [
{
path: "BR/O5/2M/00/BQ/11/BRO52M00B-Q11@3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - black",
sizes: [
"One Size"
],
price: {
original: "570,00 €",
promotional: "570,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "C1552M03M-K11",
name: "Digital watch - blue",
price: {
original: "549,00 €",
promotional: "549,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-watch-blue-c1552m03m-k11",
media: [
{
path: "C1/55/2M/03/MK/11/C1552M03M-K11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M03M-K11",
url_key: "casio-watch-blue-c1552m03m-k11",
media: [
{
path: "C1/55/2M/03/MK/11/C1552M03M-K11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Digital watch - blue",
sizes: [
"One Size"
],
price: {
original: "549,00 €",
promotional: "549,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "EA852F001-802",
name: "Chronograph watch - schwarz",
price: {
original: "529,95 €",
promotional: "529,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "emporio-armani-chronograph-watch-schwarz-ea852f001-802",
media: [
{
path: "EA/85/2F/00/18/02/EA852F001-802@3.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Emporio Armani",
is_premium: true,
family_articles: [
{
sku: "EA852F001-802",
url_key: "emporio-armani-chronograph-watch-schwarz-ea852f001-802",
media: [
{
path: "EA/85/2F/00/18/02/EA852F001-802@3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - schwarz",
sizes: [
"One Size"
],
price: {
original: "529,95 €",
promotional: "529,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "SZ752M00E-Q11",
name: "Watch - black",
price: {
original: "529,00 €",
promotional: "529,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "seiko-watch-black-sz752m00e-q11",
media: [
{
path: "SZ/75/2M/00/EQ/11/SZ752M00E-Q11@4.2.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Seiko",
is_premium: false,
family_articles: [
{
sku: "SZ752M00E-Q11",
url_key: "seiko-watch-black-sz752m00e-q11",
media: [
{
path: "SZ/75/2M/00/EQ/11/SZ752M00E-Q11@4.2.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - black",
sizes: [
"One Size"
],
price: {
original: "529,00 €",
promotional: "529,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "SZ752M012-Q11",
name: "Watch - black",
price: {
original: "529,00 €",
promotional: "529,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "seiko-watch-black-sz752m012-q11",
media: [
{
path: "SZ/75/2M/01/2Q/11/SZ752M012-Q11@4.2.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Seiko",
is_premium: false,
family_articles: [
{
sku: "SZ752M012-Q11",
url_key: "seiko-watch-black-sz752m012-q11",
media: [
{
path: "SZ/75/2M/01/2Q/11/SZ752M012-Q11@4.2.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - black",
sizes: [
"One Size"
],
price: {
original: "529,00 €",
promotional: "529,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "SZ752M00R-O11",
name: "Watch - brown",
price: {
original: "519,00 €",
promotional: "519,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "seiko-watch-brown-sz752m00r-o11",
media: [
{
path: "SZ/75/2M/00/RO/11/SZ752M00R-O11@5.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Seiko",
is_premium: false,
family_articles: [
{
sku: "SZ752M00R-O11",
url_key: "seiko-watch-brown-sz752m00r-o11",
media: [
{
path: "SZ/75/2M/00/RO/11/SZ752M00R-O11@5.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - brown",
sizes: [
"One Size"
],
price: {
original: "519,00 €",
promotional: "519,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "CT952M00L-Q11",
name: "Chronograph watch - schwarz",
price: {
original: "499,95 €",
promotional: "499,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "citizen-chronograph-watch-schwarz-ct952m00l-q11",
media: [
{
path: "CT/95/2M/00/LQ/11/CT952M00L-Q11@6.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "CT/95/2M/00/LQ/11/CT952M00L-Q11@5.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Citizen",
is_premium: true,
family_articles: [
{
sku: "CT952M00L-Q11",
url_key: "citizen-chronograph-watch-schwarz-ct952m00l-q11",
media: [
{
path: "CT/95/2M/00/LQ/11/CT952M00L-Q11@6.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - schwarz",
sizes: [
"One Size"
],
price: {
original: "499,95 €",
promotional: "499,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "CT952M00M-N11",
name: "Watch - khaki/gunmetal",
price: {
original: "499,95 €",
promotional: "499,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "citizen-watch-khakigunmetal-ct952m00m-n11",
media: [
{
path: "CT/95/2M/00/MN/11/CT952M00M-N11@6.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "CT/95/2M/00/MN/11/CT952M00M-N11@5.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Citizen",
is_premium: true,
family_articles: [
{
sku: "CT952M00M-N11",
url_key: "citizen-watch-khakigunmetal-ct952m00m-n11",
media: [
{
path: "CT/95/2M/00/MN/11/CT952M00M-N11@6.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - khaki/gunmetal",
sizes: [
"One Size"
],
price: {
original: "499,95 €",
promotional: "499,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "SZ752M00Z-D11",
name: "SOLAR - Chronograph watch - silver-coloured",
price: {
original: "499,00 €",
promotional: "499,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "seiko-solar-chronograph-watch-silver-coloured-sz752m00z-d11",
media: [
{
path: "SZ/75/2M/00/ZD/11/SZ752M00Z-D11@5.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Seiko",
is_premium: false,
family_articles: [
{
sku: "SZ752M00Z-D11",
url_key: "seiko-solar-chronograph-watch-silver-coloured-sz752m00z-d11",
media: [
{
path: "SZ/75/2M/00/ZD/11/SZ752M00Z-D11@5.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "SOLAR - Chronograph watch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "499,00 €",
promotional: "499,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "VEF54M003-K11",
name: "V-CIRCLE THE MANIFESTO EDITION - Watch - blue",
price: {
original: "489,95 €",
promotional: "489,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-v-circle-the-manifesto-edition-watch-blue-vef54m003-k11",
media: [
{
path: "VE/F5/4M/00/3K/11/VEF54M003-K11@7.2.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "VE/F5/4M/00/3K/11/VEF54M003-K11@8.2.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: false,
family_articles: [
{
sku: "VEF54M003-K11",
url_key: "versace-watches-v-circle-the-manifesto-edition-watch-blue-vef54m003-k11",
media: [
{
path: "VE/F5/4M/00/3K/11/VEF54M003-K11@7.2.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "V-CIRCLE THE MANIFESTO EDITION - Watch - blue",
sizes: [
"One Size"
],
price: {
original: "489,95 €",
promotional: "489,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "VEF54M006-Q11",
name: "V-CIRCLE THE MANIFESTO EDITION - Watch - black",
price: {
original: "489,95 €",
promotional: "489,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-v-circle-the-manifesto-edition-watch-black-vef54m006-q11",
media: [
{
path: "VE/F5/4M/00/6Q/11/VEF54M006-Q11@9.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/4M/00/6Q/11/VEF54M006-Q11@5.1.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: true,
family_articles: [
{
sku: "VEF54M006-Q11",
url_key: "versace-watches-v-circle-the-manifesto-edition-watch-black-vef54m006-q11",
media: [
{
path: "VE/F5/4M/00/6Q/11/VEF54M006-Q11@9.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "V-CIRCLE THE MANIFESTO EDITION - Watch - black",
sizes: [
"One Size"
],
price: {
original: "489,95 €",
promotional: "489,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "BB152M02N-F11",
name: "TROPHY - Chronograph watch - weiß/gold",
price: {
original: "479,95 €",
promotional: "479,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-trophy-chronograph-watch-bb152m02n-f11",
media: [
{
path: "BB/15/2M/02/NF/11/BB152M02N-F11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "BB/15/2M/02/NF/11/BB152M02N-F11@5.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "BOSS",
is_premium: false,
family_articles: [
{
sku: "BB152M02N-F11",
url_key: "boss-trophy-chronograph-watch-bb152m02n-f11",
media: [
{
path: "BB/15/2M/02/NF/11/BB152M02N-F11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "TROPHY - Chronograph watch - weiß/gold",
sizes: [
"One Size"
],
price: {
original: "479,95 €",
promotional: "479,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "C1552M02O-Q11",
name: "Chronograph watch - black",
price: {
original: "679,00 €",
promotional: "477,80 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-chronograph-watch-black-c1552m02o-q11",
media: [
{
path: "C1/55/2M/02/OQ/11/C1552M02O-Q11@4.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M02O-Q11",
url_key: "casio-chronograph-watch-black-c1552m02o-q11",
media: [
{
path: "C1/55/2M/02/OQ/11/C1552M02O-Q11@4.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - black",
sizes: [
"One Size"
],
price: {
original: "679,00 €",
promotional: "477,80 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-30%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-30%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "C1552M03N-Q11",
name: "Digital watch - black",
price: {
original: "549,00 €",
promotional: "470,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-digital-watch-black-c1552m03n-q11",
media: [
{
path: "C1/55/2M/03/NQ/11/C1552M03N-Q11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M03N-Q11",
url_key: "casio-digital-watch-black-c1552m03n-q11",
media: [
{
path: "C1/55/2M/03/NQ/11/C1552M03N-Q11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Digital watch - black",
sizes: [
"One Size"
],
price: {
original: "549,00 €",
promotional: "470,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-14%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-14%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "BRO52M005-D11",
name: "Watch - silver",
price: {
original: "470,00 €",
promotional: "470,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "bruno-soehnle-watch-silver-bro52m005-d11",
media: [
{
path: "BR/O5/2M/00/5D/11/BRO52M005-D11@5.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Bruno Söhnle",
is_premium: false,
family_articles: [
{
sku: "BRO52M005-D11",
url_key: "bruno-soehnle-watch-silver-bro52m005-d11",
media: [
{
path: "BR/O5/2M/00/5D/11/BRO52M005-D11@5.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - silver",
sizes: [
"One Size"
],
price: {
original: "470,00 €",
promotional: "470,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "BRO52M00G-O11",
name: "Watch - brown",
price: {
original: "450,00 €",
promotional: "450,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "bruno-soehnle-watch-brown-bro52m00g-o11",
media: [
{
path: "BR/O5/2M/00/GO/11/BRO52M00G-O11@4.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Bruno Söhnle",
is_premium: false,
family_articles: [
{
sku: "BRO52M00G-O11",
url_key: "bruno-soehnle-watch-brown-bro52m00g-o11",
media: [
{
path: "BR/O5/2M/00/GO/11/BRO52M00G-O11@4.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - brown",
sizes: [
"One Size"
],
price: {
original: "450,00 €",
promotional: "450,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "BB152M039-Q11",
name: "OCEAN EDITION - Chronograph watch - black/roségold-coloured",
price: {
original: "449,95 €",
promotional: "449,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-ocean-edition-watch-blackrosegold-coloured-bb152m039-q11",
media: [
{
path: "BB/15/2M/03/9Q/11/BB152M039-Q11@4.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "BB/15/2M/03/9Q/11/BB152M039-Q11@3.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "BOSS",
is_premium: false,
family_articles: [
{
sku: "BB152M039-Q11",
url_key: "boss-ocean-edition-watch-blackrosegold-coloured-bb152m039-q11",
media: [
{
path: "BB/15/2M/03/9Q/11/BB152M039-Q11@4.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "OCEAN EDITION - Chronograph watch - black/roségold-coloured",
sizes: [
"One Size"
],
price: {
original: "449,95 €",
promotional: "449,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "C1552M04N-D11",
name: "PRO TREK - Chronograph watch - silver-coloured",
price: {
original: "549,00 €",
promotional: "446,30 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-pro-trek-chronograph-watch-silver-coloured-c1552m04n-d11",
media: [
{
path: "C1/55/2M/04/ND/11/C1552M04N-D11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M04N-D11",
url_key: "casio-pro-trek-chronograph-watch-silver-coloured-c1552m04n-d11",
media: [
{
path: "C1/55/2M/04/ND/11/C1552M04N-D11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "PRO TREK - Chronograph watch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "549,00 €",
promotional: "446,30 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-19%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-19%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "VEF52M003-G11",
name: "V-CIRCLE THE CLANS EDITION - Watch - red",
price: {
original: "589,95 €",
promotional: "439,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-v-circle-the-clans-edition-watch-vef52m003-g11",
media: [
{
path: "VE/F5/2M/00/3G/11/VEF52M003-G11@8.5.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/3G/11/VEF52M003-G11@9.4.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: false,
family_articles: [
{
sku: "VEF52M003-G11",
url_key: "versace-watches-v-circle-the-clans-edition-watch-vef52m003-g11",
media: [
{
path: "VE/F5/2M/00/3G/11/VEF52M003-G11@8.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "V-CIRCLE THE CLANS EDITION - Watch - red",
sizes: [
"One Size"
],
price: {
original: "589,95 €",
promotional: "439,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M003-K11",
url_key: "versace-watches-v-circle-the-clans-edition-watch-blue-vef52m003-k11",
media: [
{
path: "VE/F5/2M/00/3K/11/VEF52M003-K11@7.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "V-CIRCLE THE CLANS EDITION - Watch - blue",
sizes: [
"One Size"
],
price: {
original: "589,95 €",
promotional: "439,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M003-Q11",
url_key: "versace-watches-v-circle-the-clans-edition-watch-vef52m003-q11",
media: [
{
path: "VE/F5/2M/00/3Q/11/VEF52M003-Q11@12.4.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "V-CIRCLE THE CLANS EDITION - Watch - black",
sizes: [
"One Size"
],
price: {
original: "489,95 €",
promotional: "367,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "VEF52M003-K11",
name: "V-CIRCLE THE CLANS EDITION - Watch - blue",
price: {
original: "589,95 €",
promotional: "439,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "versace-watches-v-circle-the-clans-edition-watch-blue-vef52m003-k11",
media: [
{
path: "VE/F5/2M/00/3K/11/VEF52M003-K11@7.5.jpg",
packet_shot: false,
role: "DEFAULT"
},
{
path: "VE/F5/2M/00/3K/11/VEF52M003-K11@9.4.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Versace Watches",
is_premium: false,
family_articles: [
{
sku: "VEF52M003-K11",
url_key: "versace-watches-v-circle-the-clans-edition-watch-blue-vef52m003-k11",
media: [
{
path: "VE/F5/2M/00/3K/11/VEF52M003-K11@7.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "V-CIRCLE THE CLANS EDITION - Watch - blue",
sizes: [
"One Size"
],
price: {
original: "589,95 €",
promotional: "439,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M003-G11",
url_key: "versace-watches-v-circle-the-clans-edition-watch-vef52m003-g11",
media: [
{
path: "VE/F5/2M/00/3G/11/VEF52M003-G11@8.5.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "V-CIRCLE THE CLANS EDITION - Watch - red",
sizes: [
"One Size"
],
price: {
original: "589,95 €",
promotional: "439,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
},
{
sku: "VEF52M003-Q11",
url_key: "versace-watches-v-circle-the-clans-edition-watch-vef52m003-q11",
media: [
{
path: "VE/F5/2M/00/3Q/11/VEF52M003-Q11@12.4.jpg",
packet_shot: false,
role: "FAMILY"
}
],
name: "V-CIRCLE THE CLANS EDITION - Watch - black",
sizes: [
"One Size"
],
price: {
original: "489,95 €",
promotional: "367,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-25%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "SZ752M010-D11",
name: "Watch - silver-coloured",
price: {
original: "439,00 €",
promotional: "439,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "seiko-watch-silver-coloured-sz752m010-d11",
media: [
{
path: "SZ/75/2M/01/0D/11/SZ752M010-D11@3.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Seiko",
is_premium: false,
family_articles: [
{
sku: "SZ752M010-D11",
url_key: "seiko-watch-silver-coloured-sz752m010-d11",
media: [
{
path: "SZ/75/2M/01/0D/11/SZ752M010-D11@3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "439,00 €",
promotional: "439,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "BB152M038-F11",
name: "OCEAN EDITION - Watch - gold-coloured",
price: {
original: "429,95 €",
promotional: "429,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-ocean-edition-watch-gold-coloured-bb152m038-f11",
media: [
{
path: "BB/15/2M/03/8F/11/BB152M038-F11@7.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "BB/15/2M/03/8F/11/BB152M038-F11@3.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "BOSS",
is_premium: false,
family_articles: [
{
sku: "BB152M038-F11",
url_key: "boss-ocean-edition-watch-gold-coloured-bb152m038-f11",
media: [
{
path: "BB/15/2M/03/8F/11/BB152M038-F11@7.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "OCEAN EDITION - Watch - gold-coloured",
sizes: [
"One Size"
],
price: {
original: "429,95 €",
promotional: "429,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "BB152M036-C11",
name: "OCEAN EDITION - Chronograph watch - dark grey",
price: {
original: "429,95 €",
promotional: "429,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-ocean-edition-chronograph-watch-dark-grey-bb152m036-c11",
media: [
{
path: "BB/15/2M/03/6C/11/BB152M036-C11@6.1.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "BB/15/2M/03/6C/11/BB152M036-C11@7.1.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "BOSS",
is_premium: false,
family_articles: [
{
sku: "BB152M036-C11",
url_key: "boss-ocean-edition-chronograph-watch-dark-grey-bb152m036-c11",
media: [
{
path: "BB/15/2M/03/6C/11/BB152M036-C11@6.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "OCEAN EDITION - Chronograph watch - dark grey",
sizes: [
"One Size"
],
price: {
original: "429,95 €",
promotional: "429,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "BB152M02Q-D11",
name: "Watch - silver-coloured/black",
price: {
original: "599,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-watch-silver-colouredblack-bb152m02q-d11",
media: [
{
path: "BB/15/2M/02/QD/11/BB152M02Q-D11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "BB/15/2M/02/QD/11/BB152M02Q-D11@5.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "BOSS",
is_premium: false,
family_articles: [
{
sku: "BB152M02Q-D11",
url_key: "boss-watch-silver-colouredblack-bb152m02q-d11",
media: [
{
path: "BB/15/2M/02/QD/11/BB152M02Q-D11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - silver-coloured/black",
sizes: [
"One Size"
],
price: {
original: "599,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-30%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-30%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "EMA52M00L-F11",
name: "Smartwatch - roségold-coloured",
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "emporio-armani-connected-watch-rosegold-coloured-ema52m00l-f11",
media: [
{
path: "EM/A5/2M/00/LF/11/EMA52M00L-F11@2.3.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "EM/A5/2M/00/LF/11/EMA52M00L-F11@6.2.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Emporio Armani Connected",
is_premium: false,
family_articles: [
{
sku: "EMA52M00L-F11",
url_key: "emporio-armani-connected-watch-rosegold-coloured-ema52m00l-f11",
media: [
{
path: "EM/A5/2M/00/LF/11/EMA52M00L-F11@2.3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Smartwatch - roségold-coloured",
sizes: [
"One Size"
],
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "smartAccessories",
value: "SMART",
tracking_value: "smart accessories"
}
]
}
],
flags: [
{
key: "smartAccessories",
value: "SMART",
tracking_value: "smart accessories"
}
],
product_group: "accessoires"
},
{
sku: "DI152M02K-Q11",
name: "BOLTDOWN - Chronograph watch - schwarz",
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "diesel-boltdown-chronograph-watch-schwarz-di152m02k-q11",
media: [
{
path: "DI/15/2M/02/KQ/11/DI152M02K-Q11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "DI/15/2M/02/KQ/11/DI152M02K-Q11@6.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Diesel",
is_premium: false,
family_articles: [
{
sku: "DI152M02K-Q11",
url_key: "diesel-boltdown-chronograph-watch-schwarz-di152m02k-q11",
media: [
{
path: "DI/15/2M/02/KQ/11/DI152M02K-Q11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "BOLTDOWN - Chronograph watch - schwarz",
sizes: [
"One Size"
],
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "EMA52M00K-Q11",
name: "Smartwatch - schwarz",
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "emporio-armani-connected-watch-schwarz-ema52m00k-q11",
media: [
{
path: "EM/A5/2M/00/KQ/11/EMA52M00K-Q11@2.2.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "EM/A5/2M/00/KQ/11/EMA52M00K-Q11@6.1.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Emporio Armani Connected",
is_premium: false,
family_articles: [
{
sku: "EMA52M00K-Q11",
url_key: "emporio-armani-connected-watch-schwarz-ema52m00k-q11",
media: [
{
path: "EM/A5/2M/00/KQ/11/EMA52M00K-Q11@2.2.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Smartwatch - schwarz",
sizes: [
"One Size"
],
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "smartAccessories",
value: "SMART",
tracking_value: "smart accessories"
}
]
}
],
flags: [
{
key: "smartAccessories",
value: "SMART",
tracking_value: "smart accessories"
}
],
product_group: "accessoires"
},
{
sku: "EMA52M00J-D11",
name: "Smartwatch - silver-coloured",
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "emporio-armani-connected-watch-silver-coloured-ema52m00j-d11",
media: [
{
path: "EM/A5/2M/00/JD/11/EMA52M00J-D11@2.2.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "EM/A5/2M/00/JD/11/EMA52M00J-D11@6.1.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Emporio Armani Connected",
is_premium: false,
family_articles: [
{
sku: "EMA52M00J-D11",
url_key: "emporio-armani-connected-watch-silver-coloured-ema52m00j-d11",
media: [
{
path: "EM/A5/2M/00/JD/11/EMA52M00J-D11@2.2.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Smartwatch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "smartAccessories",
value: "SMART",
tracking_value: "smart accessories"
}
]
}
],
flags: [
{
key: "smartAccessories",
value: "SMART",
tracking_value: "smart accessories"
}
],
product_group: "accessoires"
},
{
sku: "EMA52M00H-Q11",
name: "Smartwatch - schwarz",
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "emporio-armani-connected-watch-schwarz-ema52m00h-q11",
media: [
{
path: "EM/A5/2M/00/HQ/11/EMA52M00H-Q11@2.2.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "EM/A5/2M/00/HQ/11/EMA52M00H-Q11@6.1.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Emporio Armani Connected",
is_premium: false,
family_articles: [
{
sku: "EMA52M00H-Q11",
url_key: "emporio-armani-connected-watch-schwarz-ema52m00h-q11",
media: [
{
path: "EM/A5/2M/00/HQ/11/EMA52M00H-Q11@2.2.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Smartwatch - schwarz",
sizes: [
"One Size"
],
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "smartAccessories",
value: "SMART",
tracking_value: "smart accessories"
}
]
}
],
flags: [
{
key: "smartAccessories",
value: "SMART",
tracking_value: "smart accessories"
}
],
product_group: "accessoires"
},
{
sku: "EA852M020-Q11",
name: "Chronograph watch - schwarz",
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "emporio-armani-chronograph-watch-schwarz-ea852m020-q11",
media: [
{
path: "EA/85/2M/02/0Q/11/EA852M020-Q11@5.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "EA/85/2M/02/0Q/11/EA852M020-Q11@6.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Emporio Armani",
is_premium: false,
family_articles: [
{
sku: "EA852M020-Q11",
url_key: "emporio-armani-chronograph-watch-schwarz-ea852m020-q11",
media: [
{
path: "EA/85/2M/02/0Q/11/EA852M020-Q11@5.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - schwarz",
sizes: [
"One Size"
],
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "EMA52M00Q-D11",
name: "Smartwatch - silver-coloured",
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "emporio-armani-connected-watch-silver-coloured-ema52m00q-d11",
media: [
{
path: "EM/A5/2M/00/QD/11/EMA52M00Q-D11@8.3.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "EM/A5/2M/00/QD/11/EMA52M00Q-D11@9.2.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Emporio Armani Connected",
is_premium: false,
family_articles: [
{
sku: "EMA52M00Q-D11",
url_key: "emporio-armani-connected-watch-silver-coloured-ema52m00q-d11",
media: [
{
path: "EM/A5/2M/00/QD/11/EMA52M00Q-D11@8.3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Smartwatch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "smartAccessories",
value: "SMART",
tracking_value: "smart accessories"
}
]
}
],
flags: [
{
key: "smartAccessories",
value: "SMART",
tracking_value: "smart accessories"
}
],
product_group: "accessoires"
},
{
sku: "EA852M01H-Q11",
name: "Watch - schwarz",
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "emporio-armani-watch-schwarz-ea852m01h-q11",
media: [
{
path: "EA/85/2M/01/HQ/11/EA852M01H-Q11@2.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "EA/85/2M/01/HQ/11/EA852M01H-Q11@3.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Emporio Armani",
is_premium: true,
family_articles: [
{
sku: "EA852M01H-Q11",
url_key: "emporio-armani-watch-schwarz-ea852m01h-q11",
media: [
{
path: "EA/85/2M/01/HQ/11/EA852M01H-Q11@2.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - schwarz",
sizes: [
"One Size"
],
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "EA852M028-K11",
name: "Watch - blau",
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "emporio-armani-watch-blau-ea852m028-k11",
media: [
{
path: "EA/85/2M/02/8K/11/EA852M028-K11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "EA/85/2M/02/8K/11/EA852M028-K11@8.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Emporio Armani",
is_premium: false,
family_articles: [
{
sku: "EA852M028-K11",
url_key: "emporio-armani-watch-blau-ea852m028-k11",
media: [
{
path: "EA/85/2M/02/8K/11/EA852M028-K11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - blau",
sizes: [
"One Size"
],
price: {
original: "419,95 €",
promotional: "419,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "T0K52M02H-Q11",
name: "REBEL CERAMIC  - Chronograph watch - black",
price: {
original: "598,00 €",
promotional: "418,60 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "thomas-sabo-rebel-ceramic-chronograph-watch-black-t0k52m02h-q11",
media: [
{
path: "T0/K5/2M/02/HQ/11/T0K52M02H-Q11@20.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "T0/K5/2M/02/HQ/11/T0K52M02H-Q11@24.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "THOMAS SABO",
is_premium: false,
family_articles: [
{
sku: "T0K52M02H-Q11",
url_key: "thomas-sabo-rebel-ceramic-chronograph-watch-black-t0k52m02h-q11",
media: [
{
path: "T0/K5/2M/02/HQ/11/T0K52M02H-Q11@20.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "REBEL CERAMIC  - Chronograph watch - black",
sizes: [
"One Size"
],
price: {
original: "598,00 €",
promotional: "418,60 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "discountRate",
value: "-30%",
tracking_value: "discount rate"
}
]
}
],
flags: [
{
key: "discountRate",
value: "-30%",
tracking_value: "discount rate"
}
],
product_group: "accessoires"
},
{
sku: "EA852M024-F11",
name: "Chronograph watch - roségold-colured/silver-coloured",
price: {
original: "409,95 €",
promotional: "409,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "emporio-armani-chronograph-watch-rosegold-coluredsilver-coloured-ea852m024-f11",
media: [
{
path: "EA/85/2M/02/4F/11/EA852M024-F11@5.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "EA/85/2M/02/4F/11/EA852M024-F11@6.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Emporio Armani",
is_premium: false,
family_articles: [
{
sku: "EA852M024-F11",
url_key: "emporio-armani-chronograph-watch-rosegold-coluredsilver-coloured-ea852m024-f11",
media: [
{
path: "EA/85/2M/02/4F/11/EA852M024-F11@5.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - roségold-colured/silver-coloured",
sizes: [
"One Size"
],
price: {
original: "409,95 €",
promotional: "409,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "EA852M01S-C11",
name: "Chronograph watch - grau ip",
price: {
original: "409,95 €",
promotional: "409,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "emporio-armani-chronograph-watch-grau-ip-ea852m01s-c11",
media: [
{
path: "EA/85/2M/01/SC/11/EA852M01S-C11@2.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "EA/85/2M/01/SC/11/EA852M01S-C11@3.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Emporio Armani",
is_premium: true,
family_articles: [
{
sku: "EA852M01S-C11",
url_key: "emporio-armani-chronograph-watch-grau-ip-ea852m01s-c11",
media: [
{
path: "EA/85/2M/01/SC/11/EA852M01S-C11@2.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - grau ip",
sizes: [
"One Size"
],
price: {
original: "409,95 €",
promotional: "409,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "SZ752M00P-Q11",
name: "Watch - black",
price: {
original: "400,00 €",
promotional: "400,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "seiko-watch-black-sz752m00p-q11",
media: [
{
path: "SZ/75/2M/00/PQ/11/SZ752M00P-Q11@5.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Seiko",
is_premium: false,
family_articles: [
{
sku: "SZ752M00P-Q11",
url_key: "seiko-watch-black-sz752m00p-q11",
media: [
{
path: "SZ/75/2M/00/PQ/11/SZ752M00P-Q11@5.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - black",
sizes: [
"One Size"
],
price: {
original: "400,00 €",
promotional: "400,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "BB152M037-D11",
name: "OCEAN EDITION - Chronograph watch - silver-coloured",
price: {
original: "399,95 €",
promotional: "399,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-ocean-edition-chronograph-watch-silver-coloured-bb152m037-d11",
media: [
{
path: "BB/15/2M/03/7D/11/BB152M037-D11@5.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "BB/15/2M/03/7D/11/BB152M037-D11@3.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "BOSS",
is_premium: false,
family_articles: [
{
sku: "BB152M037-D11",
url_key: "boss-ocean-edition-chronograph-watch-silver-coloured-bb152m037-d11",
media: [
{
path: "BB/15/2M/03/7D/11/BB152M037-D11@5.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "OCEAN EDITION - Chronograph watch - silver-coloured",
sizes: [
"One Size"
],
price: {
original: "399,95 €",
promotional: "399,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "CT952M00W-D11",
name: "Watch - silver-coloured/black",
price: {
original: "399,95 €",
promotional: "399,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "citizen-watch-silver-colouredblack-ct952m00w-d11",
media: [
{
path: "CT/95/2M/00/WD/11/CT952M00W-D11@2.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "CT/95/2M/00/WD/11/CT952M00W-D11@5.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "Citizen",
is_premium: true,
family_articles: [
{
sku: "CT952M00W-D11",
url_key: "citizen-watch-silver-colouredblack-ct952m00w-d11",
media: [
{
path: "CT/95/2M/00/WD/11/CT952M00W-D11@2.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - silver-coloured/black",
sizes: [
"One Size"
],
price: {
original: "399,95 €",
promotional: "399,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "BB152M02J-D11",
name: "GRAND PRIX - Chronograph watch - silver-coloured/white",
price: {
original: "399,95 €",
promotional: "399,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-grand-prix-chronograph-watch-bb152m02j-d11",
media: [
{
path: "BB/15/2M/02/JD/11/BB152M02J-D11@6.1.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "BB/15/2M/02/JD/11/BB152M02J-D11@8.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "BOSS",
is_premium: false,
family_articles: [
{
sku: "BB152M02J-D11",
url_key: "boss-grand-prix-chronograph-watch-bb152m02j-d11",
media: [
{
path: "BB/15/2M/02/JD/11/BB152M02J-D11@6.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "GRAND PRIX - Chronograph watch - silver-coloured/white",
sizes: [
"One Size"
],
price: {
original: "399,95 €",
promotional: "399,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "BB152M011-Q11",
name: "Chronograph watch - schwarz",
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-chronograph-watch-schwarz-bb152m011-q11",
media: [
{
path: "BB/15/2M/01/1Q/11/BB152M011-Q11@6.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "BB/15/2M/01/1Q/11/BB152M011-Q11@5.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "BOSS",
is_premium: true,
family_articles: [
{
sku: "BB152M011-Q11",
url_key: "boss-chronograph-watch-schwarz-bb152m011-q11",
media: [
{
path: "BB/15/2M/01/1Q/11/BB152M011-Q11@6.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - schwarz",
sizes: [
"One Size"
],
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "BB152M032-C11",
name: "NAVIGATOR - Chronograph watch - grey",
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-navigator-chronograph-watch-bb152m032-c11",
media: [
{
path: "BB/15/2M/03/2C/11/BB152M032-C11@4.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "BB/15/2M/03/2C/11/BB152M032-C11@3.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "BOSS",
is_premium: false,
family_articles: [
{
sku: "BB152M032-C11",
url_key: "boss-navigator-chronograph-watch-bb152m032-c11",
media: [
{
path: "BB/15/2M/03/2C/11/BB152M032-C11@4.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "NAVIGATOR - Chronograph watch - grey",
sizes: [
"One Size"
],
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
},
{
sku: "BB152M032-Q11",
url_key: "boss-navigator-chronograph-watch-black-bb152m032-q11",
media: [
{
path: "BB/15/2M/03/2Q/11/BB152M032-Q11@4.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "NAVIGATOR - Chronograph watch - black",
sizes: [
"One Size"
],
price: {
original: "299,95 €",
promotional: "299,95 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "BB152M03H-C11",
name: "Chronograph watch - grey",
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-chronograph-watch-grey-bb152m03h-c11",
media: [
{
path: "BB/15/2M/03/HC/11/BB152M03H-C11@9.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "BOSS",
is_premium: false,
family_articles: [
{
sku: "BB152M03H-C11",
url_key: "boss-chronograph-watch-grey-bb152m03h-c11",
media: [
{
path: "BB/15/2M/03/HC/11/BB152M03H-C11@9.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - grey",
sizes: [
"One Size"
],
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "BB152M01R-K11",
name: "NAVIGATOR - Chronograph watch - blau",
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-navigator-chronograph-watch-blau-bb152m01r-k11",
media: [
{
path: "BB/15/2M/01/RK/11/BB152M01R-K11@6.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "BB/15/2M/01/RK/11/BB152M01R-K11@5.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "BOSS",
is_premium: true,
family_articles: [
{
sku: "BB152M01R-K11",
url_key: "boss-navigator-chronograph-watch-blau-bb152m01r-k11",
media: [
{
path: "BB/15/2M/01/RK/11/BB152M01R-K11@6.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "NAVIGATOR - Chronograph watch - blau",
sizes: [
"One Size"
],
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "POL52M00J-O11",
name: "Watch - brown",
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "pop-pilot-watch-brown-pol52m00j-o11",
media: [
{
path: "PO/L5/2M/00/JO/11/POL52M00J-O11@1.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "POP-PILOT",
is_premium: false,
family_articles: [
{
sku: "POL52M00J-O11",
url_key: "pop-pilot-watch-brown-pol52m00j-o11",
media: [
{
path: "PO/L5/2M/00/JO/11/POL52M00J-O11@1.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - brown",
sizes: [
"One Size"
],
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "BB152M012-K11",
name: "Chronograph watch - blau",
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "boss-watch-blau-bb152m012-k11",
media: [
{
path: "BB/15/2M/01/2K/11/BB152M012-K11@6.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "BB/15/2M/01/2K/11/BB152M012-K11@5.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "BOSS",
is_premium: true,
family_articles: [
{
sku: "BB152M012-K11",
url_key: "boss-watch-blau-bb152m012-k11",
media: [
{
path: "BB/15/2M/01/2K/11/BB152M012-K11@6.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - blau",
sizes: [
"One Size"
],
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "SZ752M00Y-Q11",
name: "Watch - black",
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "seiko-watch-black-sz752m00y-q11",
media: [
{
path: "SZ/75/2M/00/YQ/11/SZ752M00Y-Q11@2.1.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Seiko",
is_premium: false,
family_articles: [
{
sku: "SZ752M00Y-Q11",
url_key: "seiko-watch-black-sz752m00y-q11",
media: [
{
path: "SZ/75/2M/00/YQ/11/SZ752M00Y-Q11@2.1.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - black",
sizes: [
"One Size"
],
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "C1552M03D-Q11",
name: "Watch - black",
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "casio-watch-black-c1552m03d-q11",
media: [
{
path: "C1/55/2M/03/DQ/11/C1552M03D-Q11@3.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "Casio",
is_premium: false,
family_articles: [
{
sku: "C1552M03D-Q11",
url_key: "casio-watch-black-c1552m03d-q11",
media: [
{
path: "C1/55/2M/03/DQ/11/C1552M03D-Q11@3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Watch - black",
sizes: [
"One Size"
],
price: {
original: "399,00 €",
promotional: "399,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
]
}
],
flags: [
{
key: "new",
value: "new",
tracking_value: "new"
}
],
product_group: "accessoires"
},
{
sku: "T0K52M00M-D11",
name: "REBEL URBAN - Chronograph watch - silver-colored/black",
price: {
original: "398,00 €",
promotional: "398,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "thomas-sabo-rebel-urban-chronograph-watch-silver-colored-black-t0k52m00m-d11",
media: [
{
path: "T0/K5/2M/00/MD/11/T0K52M00M-D11@1.3.jpg",
packet_shot: true,
role: "DEFAULT"
}
],
brand_name: "THOMAS SABO",
is_premium: false,
family_articles: [
{
sku: "T0K52M00M-D11",
url_key: "thomas-sabo-rebel-urban-chronograph-watch-silver-colored-black-t0k52m00m-d11",
media: [
{
path: "T0/K5/2M/00/MD/11/T0K52M00M-D11@1.3.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "REBEL URBAN - Chronograph watch - silver-colored/black",
sizes: [
"One Size"
],
price: {
original: "398,00 €",
promotional: "398,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
},
{
sku: "T0K52M02I-Q11",
name: "Chronograph watch - bi-coloured",
price: {
original: "398,00 €",
promotional: "398,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
sizes: [
"One Size"
],
url_key: "thomas-sabo-chronograph-watch-bi-coloured-t0k52m02i-q11",
media: [
{
path: "T0/K5/2M/02/IQ/11/T0K52M02I-Q11@18.jpg",
packet_shot: true,
role: "DEFAULT"
},
{
path: "T0/K5/2M/02/IQ/11/T0K52M02I-Q11@13.jpg",
packet_shot: false,
role: "HOVER"
}
],
brand_name: "THOMAS SABO",
is_premium: false,
family_articles: [
{
sku: "T0K52M02I-Q11",
url_key: "thomas-sabo-chronograph-watch-bi-coloured-t0k52m02i-q11",
media: [
{
path: "T0/K5/2M/02/IQ/11/T0K52M02I-Q11@18.jpg",
packet_shot: true,
role: "FAMILY"
}
],
name: "Chronograph watch - bi-coloured",
sizes: [
"One Size"
],
price: {
original: "398,00 €",
promotional: "398,00 €",
has_different_prices: false,
has_different_original_prices: false,
has_different_promotional_prices: false,
has_discount_on_selected_sizes_only: false
},
flags: [ ]
}
],
flags: [ ],
product_group: "accessoires"
}
],
query_path: "/watches-men/?order=price&dir=desc",
next_page_path: "/watches-men/?p=2&order=price&dir=desc",
query_params: {
categories: "watches-men",
sort: "price_desc",
offset: "0",
limit: "84"
},
page_gender: "men",
premium: false,
filters: [
{
key: "brands",
label: "Brand",
url_key: "brand",
kind: "values",
family_values: [
{
key: "AD1",
label: "adidas Originals",
family_id: "ADID",
is_family: false
},
{
key: "ARMA",
label: "Armani",
is_family: true
},
{
key: "ARC",
label: "Armani Exchange",
family_id: "ARMA",
is_family: false
},
{
key: "ARD",
label: "Armani Exchange Connected",
family_id: "ARMA",
is_family: false
},
{
key: "BE1",
label: "Ben Sherman",
family_id: "BESH",
is_family: false
},
{
key: "BB1",
label: "BOSS",
family_id: "BOSS",
is_family: false
},
{
key: "BR0",
label: "Breil",
is_family: false
},
{
key: "BRO",
label: "Bruno Söhnle",
is_family: false
},
{
key: "CCA",
label: "C- Collection by CHRIST",
family_id: "CHRI",
is_family: false
},
{
key: "6CA",
label: "Calvin Klein",
family_id: "CALV",
is_family: false
},
{
key: "C14",
label: "Carhartt WIP",
is_family: false
},
{
key: "C15",
label: "Casio",
is_family: false
},
{
key: "CW9",
label: "CHPO",
is_family: false
},
{
key: "CHRI",
label: "CHRIST",
is_family: true
},
{
key: "CX5",
label: "CHRIST",
family_id: "CHRI",
is_family: false
},
{
key: "CT9",
label: "Citizen",
is_family: false
},
{
key: "DW2",
label: "Daniel Wellington",
is_family: false
},
{
key: "DIES",
label: "Diesel",
is_family: true
},
{
key: "DI1",
label: "Diesel",
family_id: "DIES",
is_family: false
},
{
key: "DIB",
label: "DieselON",
family_id: "DIES",
is_family: false
},
{
key: "EDB",
label: "Edifice",
is_family: false
},
{
key: "EA8",
label: "Emporio Armani",
family_id: "ARMA",
is_family: false
},
{
key: "EMA",
label: "Emporio Armani Connected",
family_id: "ARMA",
is_family: false
},
{
key: "ES1",
label: "Esprit",
family_id: "ESPR",
is_family: false
},
{
key: "FE0",
label: "Festina",
is_family: false
},
{
key: "FO00",
label: "Fossil",
is_family: true
},
{
key: "FS1",
label: "Fossil",
family_id: "FO00",
is_family: false
},
{
key: "FOA",
label: "Fossil Smartwatches",
family_id: "FO00",
is_family: false
},
{
key: "GS9",
label: "G-shock",
is_family: false
},
{
key: "GA3",
label: "GANT",
family_id: "GANT",
is_family: false
},
{
key: "G42",
label: "Garmin",
is_family: false
},
{
key: "GU1",
label: "Guess",
is_family: false
},
{
key: "HU7",
label: "HUGO",
family_id: "BOSS",
is_family: false
},
{
key: "BOSS",
label: "Hugo Boss",
is_family: true
},
{
key: "2JA",
label: "Jacques Lemans",
is_family: false
},
{
key: "JO9",
label: "JOOP!",
family_id: "JOOP",
is_family: false
},
{
key: "2KH",
label: "Kerbholz",
is_family: false
},
{
key: "K44",
label: "KIOMI",
family_id: "KI00",
is_family: false
},
{
key: "K00",
label: "Komono",
is_family: false
},
{
key: "LA2",
label: "Lacoste",
family_id: "LACO",
is_family: false
},
{
key: "LAO",
label: "Larsson & Jennings",
is_family: false
},
{
key: "LIZ",
label: "Lilienthal Berlin",
is_family: false
},
{
key: "1MI",
label: "Michael Kors",
family_id: "MICH",
is_family: false
},
{
key: "NI3",
label: "Nixon",
is_family: false
},
{
key: "NOP",
label: "Nordgreen",
is_family: false
},
{
key: "PAT",
label: "Paul Hewitt",
is_family: false
},
{
key: "PO3",
label: "Polar",
is_family: false
},
{
key: "P73",
label: "Police",
is_family: false
},
{
key: "POL",
label: "POP-PILOT",
is_family: false
},
{
key: "QU1",
label: "Quiksilver",
is_family: false
},
{
key: "SO2",
label: "s.Oliver",
family_id: "SOLI",
is_family: false
},
{
key: "SZ7",
label: "Seiko",
is_family: false
},
{
key: "2SK",
label: "Skagen",
is_family: false
},
{
key: "SKA",
label: "Skagen Connected",
is_family: false
},
{
key: "SWB",
label: "Swatch",
is_family: false
},
{
key: "SW2",
label: "Swiss Military Hanowa",
is_family: false
},
{
key: "T0K",
label: "THOMAS SABO",
is_family: false
},
{
key: "TI1",
label: "Timberland",
is_family: false
},
{
key: "TX1",
label: "Timex",
is_family: false
},
{
key: "TO1",
label: "Tommy Hilfiger",
family_id: "TOMM",
is_family: false
},
{
key: "QT0",
label: "TomTom",
is_family: false
},
{
key: "TR8",
label: "Triwa",
is_family: false
},
{
key: "VERS",
label: "Versace",
is_family: true
},
{
key: "VEF",
label: "Versace Watches",
family_id: "VERS",
is_family: false
},
{
key: "VE0",
label: "Versus Versace",
family_id: "VERS",
is_family: false
},
{
key: "YO1",
label: "YOURTURN",
family_id: "YOUR",
is_family: false
}
],
family_key: "brand_families"
},
{
key: "prices",
label: "Price",
url_key: "price",
kind: "range",
range: {
min: 10,
max: 1419.95,
unit: {
symbol: "€",
position: "suffix"
}
}
},
{
key: "colors",
label: "Colour",
url_key: "color",
kind: "values",
values: [
{
key: "BLACK",
label: "Black"
},
{
key: "BROWN",
label: "Brown"
},
{
key: "BEIGE",
label: "Beige"
},
{
key: "GRAY",
label: "Grey"
},
{
key: "WHITE",
label: "White"
},
{
key: "BLUE",
label: "Blue"
},
{
key: "TURQUOISE",
label: "Turquoise"
},
{
key: "GREEN",
label: "Green"
},
{
key: "OLIVE",
label: "Olive"
},
{
key: "YELLOW",
label: "Yellow"
},
{
key: "ORANGE",
label: "Orange"
},
{
key: "RED",
label: "Red"
},
{
key: "PINK",
label: "Pink"
},
{
key: "PURPLE",
label: "Lilac"
},
{
key: "GOLD",
label: "Gold"
},
{
key: "SILVER",
label: "Silver"
},
{
key: "MULTICOLORED",
label: "Multi-coloured"
}
]
},
{
key: "sales",
label: "Sale",
url_key: "sale",
kind: "single_value",
values: [
{
key: "SALE",
label: "Only special offers"
}
]
},
{
key: "seasons",
label: "Collection",
url_key: "season_name",
kind: "values",
values: [
{
key: "SUMMER",
label: "Spring/Summer"
},
{
key: "WINTER",
label: "Autumn/Winter"
}
]
},
{
key: "activation_dates",
label: "New products",
url_key: "activation_date",
kind: "values",
values: [
{
key: "THIS_WEEK",
label: "This week"
},
{
key: "LAST_WEEK",
label: "Last week"
},
{
key: "LAST_MONTH",
label: "Last month"
}
]
},
{
key: "shipped_by_zalando",
label: "Shipped by Zalando",
url_key: "shipped_by_zalando",
kind: "single_value",
values: [
{
key: "true",
label: "Shipped by Zalando"
}
]
}
],
total_article_count: 1713,
plusStatus: "unknown",
categoryTree: [
{
label: "Accessories",
id: "3660",
url_key: "mens-accessories",
has_skus: true,
selected: false,
has_children: true,
full_url: "/mens-accessories/?order=price&dir=desc",
children: [
{
label: "Bags & cases",
id: "3661",
url_key: "bags-accessories-bags-men",
has_skus: true,
selected: false,
has_children: true,
full_url: "/bags-accessories-bags-men/?order=price&dir=desc",
children: [ ],
article_count: 6587
},
{
label: "Beanies, hats & caps",
id: "3670",
url_key: "hats-caps-men",
has_skus: true,
selected: false,
has_children: true,
full_url: "/hats-caps-men/?order=price&dir=desc",
children: [ ],
article_count: 1265
},
{
label: "Watches",
id: "3674",
url_key: "watches-men",
has_skus: true,
selected: true,
has_children: true,
full_url: "/watches-men/?order=price&dir=desc",
children: [
{
label: "Analogue watches",
id: "19435",
url_key: "analogue-watches-men",
has_skus: true,
selected: false,
has_children: false,
full_url: "/analogue-watches-men/?order=price&dir=desc",
children: [ ],
article_count: 1039
},
{
label: "Digital watches",
id: "19436",
url_key: "digital-watches-men",
has_skus: true,
selected: false,
has_children: false,
full_url: "/digital-watches-men/?order=price&dir=desc",
children: [ ],
article_count: 117
},
{
label: "Chronographs",
id: "19437",
url_key: "chronographs-men",
has_skus: true,
selected: false,
has_children: false,
full_url: "/chronographs-men/?order=price&dir=desc",
children: [ ],
article_count: 509
},
{
label: "Smartwatches",
id: "219367044",
url_key: "smartwatches-men",
has_skus: true,
selected: false,
has_children: false,
full_url: "/smartwatches-men/?order=price&dir=desc",
children: [ ],
article_count: 54
}
],
article_count: 1713
},
{
label: "Sunglasses",
id: "3678",
url_key: "sunglasses-men",
has_skus: true,
selected: false,
has_children: false,
full_url: "/sunglasses-men/?order=price&dir=desc",
children: [ ],
article_count: 1434
},
{
label: "Belts",
id: "3669",
url_key: "bags-accessories-belts-men",
has_skus: true,
selected: false,
has_children: true,
full_url: "/bags-accessories-belts-men/?order=price&dir=desc",
children: [ ],
article_count: 1274
},
{
label: "Jewellery",
id: "3673",
url_key: "bags-accessories-jewellery-men",
has_skus: true,
selected: false,
has_children: true,
full_url: "/bags-accessories-jewellery-men/?order=price&dir=desc",
children: [ ],
article_count: 1096
},
{
label: "Wallets & card holders",
id: "13132",
url_key: "wallets-card-holders-men",
has_skus: true,
selected: false,
has_children: true,
full_url: "/wallets-card-holders-men/?order=price&dir=desc",
children: [ ],
article_count: 1082
},
{
label: "Ties & accessories",
id: "9631",
url_key: "accessories-men-ties",
has_skus: true,
selected: false,
has_children: true,
full_url: "/accessories-men-ties/?order=price&dir=desc",
children: [ ],
article_count: 716
},
{
label: "Scarves & Shawls",
id: "3672",
url_key: "bags-accessories-scarves-shawls-men",
has_skus: true,
selected: false,
has_children: true,
full_url: "/bags-accessories-scarves-shawls-men/?order=price&dir=desc",
children: [ ],
article_count: 226
},
{
label: "Headphones",
id: "3679",
url_key: "headphones-men",
has_skus: true,
selected: false,
has_children: false,
full_url: "/headphones-men/?order=price&dir=desc",
children: [ ],
article_count: 136
},
{
label: "Gloves",
id: "3671",
url_key: "gloves-men",
has_skus: true,
selected: false,
has_children: true,
full_url: "/gloves-men/?order=price&dir=desc",
children: [ ],
article_count: 53
},
{
label: "Umbrellas",
id: "19443",
url_key: "umbrellas-men",
has_skus: true,
selected: false,
has_children: false,
full_url: "/umbrellas-men/?order=price&dir=desc",
children: [ ],
article_count: 77
},
{
label: "Miscellaneous",
id: "3680",
url_key: "bags-accessories-miscellaneous-men",
has_skus: true,
selected: false,
has_children: false,
full_url: "/bags-accessories-miscellaneous-men/?order=price&dir=desc",
children: [ ],
article_count: 123
}
],
article_count: 15742
}
],
sortingKeys: [
{
type: "popularity",
dir: "desc",
label: "Most popular"
},
{
type: "activation_date",
dir: "desc",
label: "New In"
},
{
type: "price_asc",
dir: "asc",
label: "Lowest price"
},
{
type: "price_desc",
dir: "desc",
label: "Highest price"
},
{
type: "sale",
dir: "desc",
label: "Sale"
}
],
breadcrumbs: [
{
items: [
{
label: "Men",
url_key: "men",
full_url: "/men/?order=price&dir=desc"
},
{
label: "Accessories",
url_key: "mens-accessories",
full_url: "/mens-accessories/?order=price&dir=desc"
},
{
label: "Watches",
url_key: "watches-men",
full_url: "/watches-men/?order=price&dir=desc"
}
]
}
],
querySemantics: {
positive_filters: [
{
key: "categories",
url_key: "category",
kind: "values",
values: [
{
key: "watches-men",
url_key: "watches-men",
label: "Watches",
seo_label: "Men’s watches",
reset_url: "/?order=price&dir=desc",
id: "3674"
}
]
}
],
negative_filters: [ ],
reset_query_url: "/watches-men/?order=price&dir=desc",
reset_url: "/watches-men/?order=price&dir=desc",
app_url: "?urlKey=watches-men&order=price&dir=desc&appdomainId=1"
},
articlesToShow: 84,
octopusTests: [ ],
locale: "en-GB",
isLoggedIn: false,
notification: null,
resetFilters: {
categories: [
{
key: "watches-men",
url_key: "watches-men",
label: "Watches",
seo_label: "Men’s watches",
reset_url: "/?order=price&dir=desc",
id: "3674"
}
]
},
selectedFilters: {
categories: [
"watches-men"
]
},
ssrArticleCount: 32,
feedbackId: "5c111f0b8753b76d87451292",
variants: {
fullWidthCatalog: false,
showHideFilters: true,
premiumCatalog: false,
inlineNavbar: false,
paginationType: "pagination",
showInGridFilter: null,
emphasizedBreadcrumbEnabled: false,
myBrandsFilter: true,
akamaiImage: true,
hideCategories: false,
wlLoggedOutHeart: true,
mobileLightFilters: false,
sizeOnBoardingDialogDesign: "grey_background"
},
searchDialog: null,
contentPositions: {
in-cat-carousel: 9,
in-cat-carousel-mobile: 6,
in-cat-carousel-fullwidth: 8,
in-cat-teaser: 9,
upper-in-cat-teaser: 5,
entry-point-teasers: [
7,
14,
20,
26
],
in-grid-filter: 4,
size-dialog: 12,
search-dialog: [
9,
19
],
search-dialog-mobile: [
8,
15
],
search-dialog-fullwidth: [
12,
25
],
sneaker-carousel: [
12
],
outfits: [
5,
14,
23
],
outfits-mobile: [
5,
11,
17,
23
],
outfits-fullwidth: [
7,
19,
31,
43
]
},
seoText: null,
teaser: {
content: {
creative_format: "TEASER",
brand: {
name: "Fossil Q",
code: "FOA"
},
pixels: [
"https://creativefactory.zalando.de/impressions/44f345d5-ab3b-4ec6-aa2a-037b7d0c3f41/7cd04534-fbe1-4f7a-bb6a-9725f966718c/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=0e01f346-0fd5-4739-a45e-eef9faf7110f&timeUnit=DAY&timeUnitCount=1&uuid=37da964f-0cd2-4adc-9c84-b9973fa94a30&bid=null&requestId=757bb6c4-60f1-4472-97d4-0de01b9314ea&s=7ED2B6305DA7749A9B29777666A32366"
],
images: [
{
aspect_ratio: null,
max_screen_size: 600,
image_url: "https://mosaic03.ztat.net/crt/creative-content/d4ffadf1-7975-4d2f-9288-d3a69b823ea8.jpg",
image_width: null
},
{
aspect_ratio: null,
max_screen_size: 1200,
image_url: "https://mosaic03.ztat.net/crt/creative-content/8ad523f6-a85d-4269-be9e-08149d8f360f.jpg",
image_width: null
}
],
creative_id: "0e01f346-0fd5-4739-a45e-eef9faf7110f",
campaign_id: "44f345d5-ab3b-4ec6-aa2a-037b7d0c3f41",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_Category Ad_CL-1002345",
text_fields: {
cta: "Shop Fossil Sport ",
bg_color: "#FFFFFF",
sales_template: "None"
},
tracking_events: {
impression: {
type: "advertising-event",
advertising-category: "category",
advertising-action: "teaser impression",
advertising-parameter: {
channel_name: "CF",
brand_code: "FOA",
billing_method: "CPC",
time_unit_count: 1,
shop_slot_id: "catalog",
creative_id: "0e01f346-0fd5-4739-a45e-eef9faf7110f",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_Category Ad_CL-1002345",
slot_id: "21672e65-4b93-4cd0-9943-404c19eece9a",
flow_id: "uF59qKvkkT0nH3IP",
price: 0.5127010396197614,
time_unit: "DAY",
campaign_source_id: "undefined",
request_id: "757bb6c4-60f1-4472-97d4-0de01b9314ea",
campaign_id: "44f345d5-ab3b-4ec6-aa2a-037b7d0c3f41"
}
},
view: {
type: "teaser view",
category: "category",
label: "catalog.teaser",
id: "0e01f346-0fd5-4739-a45e-eef9faf7110f",
name: "Shop Fossil Sport ",
parameters: {
dimension172: {
channel_name: "CF",
brand_code: "FOA",
billing_method: "CPC",
time_unit_count: 1,
shop_slot_id: "catalog",
creative_id: "0e01f346-0fd5-4739-a45e-eef9faf7110f",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_Category Ad_CL-1002345",
slot_id: "21672e65-4b93-4cd0-9943-404c19eece9a",
flow_id: "uF59qKvkkT0nH3IP",
price: 0.5127010396197614,
time_unit: "DAY",
campaign_source_id: "undefined",
request_id: "757bb6c4-60f1-4472-97d4-0de01b9314ea",
campaign_id: "44f345d5-ab3b-4ec6-aa2a-037b7d0c3f41"
}
}
},
click: {
type: "teaser click",
category: "category",
label: "catalog.teaser",
id: "0e01f346-0fd5-4739-a45e-eef9faf7110f",
name: "Shop Fossil Sport ",
parameters: {
dimension172: {
channel_name: "CF",
brand_code: "FOA",
billing_method: "CPC",
time_unit_count: 1,
shop_slot_id: "catalog",
creative_id: "0e01f346-0fd5-4739-a45e-eef9faf7110f",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_Category Ad_CL-1002345",
slot_id: "21672e65-4b93-4cd0-9943-404c19eece9a",
flow_id: "uF59qKvkkT0nH3IP",
price: 0.5127010396197614,
time_unit: "DAY",
campaign_source_id: "undefined",
request_id: "757bb6c4-60f1-4472-97d4-0de01b9314ea",
campaign_id: "44f345d5-ab3b-4ec6-aa2a-037b7d0c3f41"
}
}
}
},
view_pixels: [
"https://creativefactory.zalando.de/views/44f345d5-ab3b-4ec6-aa2a-037b7d0c3f41/7cd04534-fbe1-4f7a-bb6a-9725f966718c/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=0e01f346-0fd5-4739-a45e-eef9faf7110f&timeUnit=DAY&timeUnitCount=1&uuid=06f230c8-1a8b-4461-bda4-9601bbaa6f74&bid=null&requestId=757bb6c4-60f1-4472-97d4-0de01b9314ea&s=71FAC35C7F40B9E4ECD7620E91F8AE8F"
],
tracking_data: {
explicit_tracking_params: {
flow_id: "uF59qKvkkT0nH3IP",
entity_id: null,
shop_slot_id: "catalog",
brand_code: "FOA",
campaign_source_id: null,
campaign_id: "44f345d5-ab3b-4ec6-aa2a-037b7d0c3f41",
creative_id: "0e01f346-0fd5-4739-a45e-eef9faf7110f",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_Category Ad_CL-1002345",
target_entity_id: null
},
cf_tracking_params: {
channel_name: "CF",
brand_code: "FOA",
billing_method: "CPC",
time_unit_count: 1,
shop_slot_id: "catalog",
creative_id: "0e01f346-0fd5-4739-a45e-eef9faf7110f",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_Category Ad_CL-1002345",
slot_id: "21672e65-4b93-4cd0-9943-404c19eece9a",
flow_id: "uF59qKvkkT0nH3IP",
price: 0.5127010396197614,
time_unit: "DAY",
campaign_source_id: "undefined",
request_id: "757bb6c4-60f1-4472-97d4-0de01b9314ea",
campaign_id: "44f345d5-ab3b-4ec6-aa2a-037b7d0c3f41"
}
},
click_url: "https://creativefactory.zalando.de/clicks/44f345d5-ab3b-4ec6-aa2a-037b7d0c3f41?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=0e01f346-0fd5-4739-a45e-eef9faf7110f&requestId=757bb6c4-60f1-4472-97d4-0de01b9314ea&bid=513&redirectUrl=https%3A%2F%2Fen.zalando.de%2Fmen%2Ffossil-q%2F&vco=7cd04534-fbe1-4f7a-bb6a-9725f966718c&s=29917CD7E083AA7AC76B9EE36E6EF2EF"
},
channel_name: "CF",
slot_id: "21672e65-4b93-4cd0-9943-404c19eece9a"
},
inCatalogTeaser: {
content: {
creative_format: "TEASER",
brand: {
name: "Fossil Q",
code: "FOA"
},
pixels: [
"https://creativefactory.zalando.de/impressions/a27eb85f-cb7a-4da2-b9bb-92bf3b387f7d/7cd04534-fbe1-4f7a-bb6a-9725f966718c/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=cbb01719-b75b-458b-b757-eaa0f5962d14&timeUnit=DAY&timeUnitCount=1&uuid=47003f66-c922-422f-86ed-6ce199516ac0&bid=null&requestId=933177f2-0e58-4274-b522-2e97bed60517&s=FF27600581012F8CC51FDF897C0F276E"
],
images: [
{
aspect_ratio: "9:13",
max_screen_size: 600,
image_url: "https://mosaic03.ztat.net/crt/creative-content/6b3fffe4-80ce-47a5-a387-bc955e3f028a.jpg",
image_width: 792
}
],
creative_id: "cbb01719-b75b-458b-b757-eaa0f5962d14",
campaign_id: "a27eb85f-cb7a-4da2-b9bb-92bf3b387f7d",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_In-Catalog Ad_CL-1002353",
text_fields: {
cta: "Shop Fossil Sport ",
bg_color: "#FFFFFF",
title: "Fossil Sport ",
sales_template: "None"
},
tracking_events: {
impression: {
type: "advertising-event",
advertising-category: "catalog",
advertising-action: "teaser impression",
advertising-parameter: {
channel_name: "CF",
brand_code: "FOA",
billing_method: "CPC",
time_unit_count: 1,
shop_slot_id: "in_catalog",
creative_id: "cbb01719-b75b-458b-b757-eaa0f5962d14",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_In-Catalog Ad_CL-1002353",
slot_id: "cb224cac-736d-4e00-b757-d8a8007ef951",
flow_id: "uF59qKvkkT0nH3IP",
price: 0.8844290179196891,
time_unit: "DAY",
campaign_source_id: "undefined",
request_id: "933177f2-0e58-4274-b522-2e97bed60517",
campaign_id: "a27eb85f-cb7a-4da2-b9bb-92bf3b387f7d"
}
},
view: {
type: "teaser view",
category: "catalog",
label: "in_catalog.teaser",
id: "cbb01719-b75b-458b-b757-eaa0f5962d14",
name: "Fossil Sport ",
parameters: {
dimension172: {
channel_name: "CF",
brand_code: "FOA",
billing_method: "CPC",
time_unit_count: 1,
shop_slot_id: "in_catalog",
creative_id: "cbb01719-b75b-458b-b757-eaa0f5962d14",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_In-Catalog Ad_CL-1002353",
slot_id: "cb224cac-736d-4e00-b757-d8a8007ef951",
flow_id: "uF59qKvkkT0nH3IP",
price: 0.8844290179196891,
time_unit: "DAY",
campaign_source_id: "undefined",
request_id: "933177f2-0e58-4274-b522-2e97bed60517",
campaign_id: "a27eb85f-cb7a-4da2-b9bb-92bf3b387f7d"
}
}
},
click: {
type: "teaser click",
category: "catalog",
label: "in_catalog.teaser",
id: "cbb01719-b75b-458b-b757-eaa0f5962d14",
name: "Fossil Sport ",
parameters: {
dimension172: {
channel_name: "CF",
brand_code: "FOA",
billing_method: "CPC",
time_unit_count: 1,
shop_slot_id: "in_catalog",
creative_id: "cbb01719-b75b-458b-b757-eaa0f5962d14",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_In-Catalog Ad_CL-1002353",
slot_id: "cb224cac-736d-4e00-b757-d8a8007ef951",
flow_id: "uF59qKvkkT0nH3IP",
price: 0.8844290179196891,
time_unit: "DAY",
campaign_source_id: "undefined",
request_id: "933177f2-0e58-4274-b522-2e97bed60517",
campaign_id: "a27eb85f-cb7a-4da2-b9bb-92bf3b387f7d"
}
}
}
},
view_pixels: [
"https://creativefactory.zalando.de/views/a27eb85f-cb7a-4da2-b9bb-92bf3b387f7d/7cd04534-fbe1-4f7a-bb6a-9725f966718c/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=cbb01719-b75b-458b-b757-eaa0f5962d14&timeUnit=DAY&timeUnitCount=1&uuid=f6bd28ec-480d-4e34-b78b-8b253096e678&bid=null&requestId=933177f2-0e58-4274-b522-2e97bed60517&s=D99DCB8894E1840F59E46BC08E82EE33"
],
tracking_data: {
explicit_tracking_params: {
flow_id: "uF59qKvkkT0nH3IP",
entity_id: null,
shop_slot_id: "in_catalog",
brand_code: "FOA",
campaign_source_id: null,
campaign_id: "a27eb85f-cb7a-4da2-b9bb-92bf3b387f7d",
creative_id: "cbb01719-b75b-458b-b757-eaa0f5962d14",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_In-Catalog Ad_CL-1002353",
target_entity_id: null
},
cf_tracking_params: {
channel_name: "CF",
brand_code: "FOA",
billing_method: "CPC",
time_unit_count: 1,
shop_slot_id: "in_catalog",
creative_id: "cbb01719-b75b-458b-b757-eaa0f5962d14",
campaign_name: "Fossil_Fossil_Smartwatches_SS19_1905_DE_Men_In-Catalog Ad_CL-1002353",
slot_id: "cb224cac-736d-4e00-b757-d8a8007ef951",
flow_id: "uF59qKvkkT0nH3IP",
price: 0.8844290179196891,
time_unit: "DAY",
campaign_source_id: "undefined",
request_id: "933177f2-0e58-4274-b522-2e97bed60517",
campaign_id: "a27eb85f-cb7a-4da2-b9bb-92bf3b387f7d"
}
},
click_url: "https://creativefactory.zalando.de/clicks/a27eb85f-cb7a-4da2-b9bb-92bf3b387f7d?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=cbb01719-b75b-458b-b757-eaa0f5962d14&requestId=933177f2-0e58-4274-b522-2e97bed60517&bid=884&redirectUrl=https%3A%2F%2Fen.zalando.de%2Fmen%2Ffossil-q%2F&vco=7cd04534-fbe1-4f7a-bb6a-9725f966718c&s=F1D7089349DFA396B4C2B3AACE44B0B4"
},
channel_name: "CF",
slot_id: "cb224cac-736d-4e00-b757-d8a8007ef951"
},
entryPointTeasers: null,
upperInCatTeaser: null,
collection: null,
carouselTeaser: null,
wishlist: null,
pills: null,
styleYourKicks: null,
sizeOnboardingDialog: null
}
print(response)
results = response.json()
results


flattened_data = json_normalize(results)
print(flattened_data)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#   File "<ipython-input-4-2e0a9bc5aa26>", line 7101
#     in-cat-carousel: 9,
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = requests.get(url)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-785229211306> in <module>
#       1 # Get the total number of pages
# ----> 2 total_pages=results['pagination']['page_count']
#       3
#       4 # Your code
#       5 df=pd.DataFrame()
#
# NameError: name 'results' is not defined

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
